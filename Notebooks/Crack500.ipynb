# %% [markdown]
# ### dataset = Crack 500

# %% [markdown]
# ## Loading the important libraries and Dataset

# %%
! nvidia-smi
# Out:
# Sat Jul 18 15:19:30 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.51.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# %tensorflow_version 2.x

# %%
import os
import cv2
import shutil
import math
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import tensorflow as tf
from tensorflow import keras
import tensorflow.keras.backend as K
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Conv2DTranspose, Add, concatenate, average, Dropout
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score
from albumentations import Compose, OneOf, Flip, Rotate, RandomContrast, RandomGamma, RandomBrightness, ElasticTransform, GridDistortion, OpticalDistortion, RGBShift, CLAHE

# %%
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from skimage.transform import resize
from sklearn.metrics import classification_report

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import zipfile
local_zip = '/content/drive/My Drive/Crack/CRACK500.zip'

zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall()
zip_ref.close()
print("Done")
# Out:
# Done

# %% [markdown]
# ### Loading the data and splitting it into training and validation set.

# %%
train_image_dir = r'/content/CRACK500/traindata/image'
train_mask_dir = r'/content/CRACK500/traindata/mask'

valid_image_dir = '/content/CRACK500/valdata/image'
valid_mask_dir = '/content/CRACK500/valdata/mask'

test_image_dir = '/content/CRACK500/testdata/image'
test_mask_dir = '/content/CRACK500/testdata/mask'

# %%
test_image_dir = '/content/CRACK500_CROP/testcrop/image'
test_mask_dir = '/content/CRACK500_CROP/testcrop/mask'
test_image_paths = sorted([os.path.join(test_image_dir, fname) for fname in os.listdir(test_image_dir) if fname.endswith(".jpg") and not fname.startswith(".")])
test_mask_paths = sorted([os.path.join(test_mask_dir, fname) for fname in os.listdir(test_mask_dir) if fname.endswith(".png") and not fname.startswith(".")])
print("Number of testing images : ", len(test_image_paths))
print("Number of testing masks : ", len(test_mask_paths))
# Out:
# Number of testing images :  1124
# Number of testing masks :  1124

# %%
# Shuffle
import random
combined = list(zip(train_image_paths, train_mask_paths))
random.shuffle(combined)
train_image_paths[:], train_mask_paths[:] = zip(*combined)

# %%
# Splitting
train_image_files = train_image_paths[:1500]
train_mask_files = train_mask_paths[:1500]

valid_image_files = train_image_paths[1500:]
valid_mask_files = train_mask_paths[1500:]

print(len(train_image_files), len(train_mask_files))
print(len(valid_image_files), len(valid_mask_files))
# Out:
# 1500 1500
# 396 396

# %%
batch_size = 5
img_dim=(256, 256)

# %% [markdown]
# # Generator to load and augment the image batch wise

# %%
class Generator(Sequence):

  def __init__(self, x_set, y_set, batch_size=5, img_dim=(128, 128), augment=False):
      self.x = x_set
      self.y = y_set
      self.batch_size = batch_size
      self.img_dim = img_dim
      self.augment = augment

  def __len__(self):
      return math.ceil(len(self.x) / self.batch_size)

  augmentations = Compose(
    [                   
      Flip(p=0.7),
      Rotate(p=0.7),
      OneOf([
              RandomContrast(),
              RandomGamma(),
              RandomBrightness()
            ], p=0.3),
      OneOf([
              ElasticTransform(alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03),
              GridDistortion(),
              OpticalDistortion(distort_limit=2, shift_limit=0.5)
            ], p=0.3),
    ])

  def __getitem__(self, idx):
      batch_x = self.x[idx * self.batch_size:(idx + 1) * self.batch_size]
      batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]

      batch_x = np.array([cv2.resize(cv2.cvtColor(cv2.imread(file_name, -1), cv2.COLOR_BGR2RGB), (self.img_dim[1], self.img_dim[0])) for file_name in batch_x])
      batch_y = np.array([(cv2.resize(cv2.imread(file_name, -1), (self.img_dim[1], self.img_dim[0]))>0).astype(np.uint8) for file_name in batch_y])

      if self.augment is True:
        aug = [self.augmentations(image=i, mask=j) for i, j in zip(batch_x, batch_y)]
        batch_x = np.array([i['image'] for i in aug])
        batch_y = np.array([j['mask'] for j in aug])

      batch_y = np.expand_dims(batch_y, -1)

      return batch_x/255, batch_y/1

# %%
test1_generator=Generator(test_image_paths,test_mask_paths)

# %%
# Validation generator samples (Un-augmented)
for i, j in test1_generator:
    break

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Images', fontsize=15)
axes = axes.flatten()
for img, ax in zip(i[:5], axes[:5]):
    ax.imshow(img)
    ax.axis('off')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Masks', fontsize=15)
axes = axes.flatten()
for img, ax in zip(j[:5], axes[:5]):
    ax.imshow(np.squeeze(img, -1), cmap='gray')
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
train_generator = Generator(train_image_files, train_mask_files)
validation_generator = Generator(valid_image_files, valid_mask_files)

# %%
for i, j in train_generator:
  break

print(i.shape)
print(j.shape)
# Out:
# (5, 128, 128, 3)
# (5, 128, 128, 1)

# %%
for i, j in validation_generator:
  break

print(i.shape)
print(j.shape)
# Out:
# (5, 128, 128, 3)
# (5, 128, 128, 1)

# %%
# Train generator samples (Un-augmented)
for i, j in train_generator:
    break

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Images', fontsize=15)
axes = axes.flatten()
for img, ax in zip(i[:5], axes[:5]):
    ax.imshow(img)
    ax.axis('off')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Masks', fontsize=15)
axes = axes.flatten()
for img, ax in zip(j[:5], axes[:5]):
    ax.imshow(np.squeeze(img, -1), cmap='gray')
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
# Validation generator samples (Un-augmented)
for i, j in validation_generator:
    break

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Images', fontsize=15)
axes = axes.flatten()
for img, ax in zip(i[:5], axes[:5]):
    ax.imshow(img)
    ax.axis('off')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Masks', fontsize=15)
axes = axes.flatten()
for img, ax in zip(j[:5], axes[:5]):
    ax.imshow(np.squeeze(img, -1), cmap='gray')
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
tg = Generator(train_image_files, train_mask_files, batch_size, img_dim, augment = True)
vg = Generator(valid_image_files, valid_mask_files, batch_size, img_dim, augment = False)

# %%
for i, j in tg:
  break

print(i.shape)
print(j.shape)
# Out:
# (5, 256, 256, 3)
# (5, 256, 256, 1)

# %%
for i, j in vg:
  break

print(i.shape)
print(j.shape)
# Out:
# (5, 256, 256, 3)
# (5, 256, 256, 1)

# %%
# Augmented train
for i, j in tg:
    break

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Augmented Images', fontsize=15)
axes = axes.flatten()
for img, ax in zip(i[:5], axes[:5]):
    ax.imshow(img)
    ax.axis('off')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Augmented Masks', fontsize=15)
axes = axes.flatten()
for img, ax in zip(j[:5], axes[:5]):
    ax.imshow(np.squeeze(img, -1), cmap='gray')
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model

# %%
import numpy as np
from tensorflow.keras.backend import int_shape
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Add, BatchNormalization, Input, Activation, Concatenate
from keras.regularizers import l2

# %%
# BatchNormalization and Activation
def BN_Act(x, act = True):
    x = BatchNormalization()(x)
    if act == True:
        x = Activation("relu")(x)
    return x

# %%
#conv2d block
def conv2d_block(x, filters, kernel_size = (3, 3), padding = "same", strides = 1):
    conv = BN_Act(x)
    conv = Conv2D(filters, kernel_size, padding = padding, strides = strides)(conv)
    return conv

# %%
#Fixed layer.
def stem(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    conv = Conv2D(filters, kernel_size, padding = padding, strides = strides)(x)
    conv = conv2d_block(conv, filters, kernel_size = kernel_size, padding = padding, strides = strides)
    
    #skip
    shortcut = Conv2D(filters, kernel_size = (1, 1), padding = padding, strides = strides)(x)
    shortcut = BN_Act(shortcut, act = False) # No activation in skip connection
    
    output = Add()([conv, shortcut])
    return output

# %%
# Residual Block
def residual_block(x, filters, kernel_size = (3, 3), padding = "same", strides = 1):
    res = conv2d_block(x, filters, kernel_size = kernel_size, padding = padding, strides = strides)
    res = conv2d_block(res, filters, kernel_size = kernel_size, padding = padding, strides = 1)
    
    shortcut = Conv2D(filters, kernel_size = (1, 1), padding = padding, strides = strides)(x)
    shortcut = BN_Act(shortcut, act = False) # No activation in skip connection
    
    output = Add()([shortcut, res])
    return output

# %%
# Upsampling Concatenation block
def upsample_concat_block(x, xskip):
    u = UpSampling2D((2, 2))(x)
    c = Concatenate()([u, xskip])
    return c

# %%
# MODEL
def ResUNet():
    f = [16, 32, 64, 128, 256]
    inputs = Input((img_dim[0], img_dim[1], 3))
    
    ## Encoder/downsampling/contracting path
    e0 = inputs
    e1 = stem(e0, f[0])
    e2 = residual_block(e1, f[1], strides = 2)
    e3 = residual_block(e2, f[2], strides = 2)
    e4 = residual_block(e3, f[3], strides = 2)
    e5 = residual_block(e4, f[4], strides = 2)
    
    ## Bridge/Bottleneck
    b0 = conv2d_block(e5, f[4], strides = 1)
    b1 = conv2d_block(b0, f[4], strides = 1)
    
    ## Decoder/upsampling/expansive path
    u1 = upsample_concat_block(b1, e4)
    d1 = residual_block(u1, f[4])
    
    u2 = upsample_concat_block(d1, e3)
    d2 = residual_block(u2, f[3])
    
    u3 = upsample_concat_block(d2, e2)
    d3 = residual_block(u3, f[2])
    
    u4 = upsample_concat_block(d3, e1)
    d4 = residual_block(u4, f[1])
    
    outputs = Conv2D(1, (1, 1), padding = "same", activation = "sigmoid")(d4)
    model = Model(inputs, outputs)
    return model

# %%
K.clear_session()
model = ResUNet()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 16) 64          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 256, 256, 16) 0           conv2d_1[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256, 256, 16) 64          add[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 4640        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 32) 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 32) 544         add[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 32) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 32) 128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 32) 9248        activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 32) 0           batch_normalization_4[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 32) 128         add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 32) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 64)   18496       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 64)   2112        add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 64)   0           batch_normalization_7[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 128)  73856       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 128)  8320        add_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 128)  147584      activation_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 128)  0           batch_normalization_10[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 128)  512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 256)  295168      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 256)  33024       add_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 256)  590080      activation_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 256)  0           batch_normalization_13[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 256)  1024        add_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 256)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 256)  590080      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 256)  590080      activation_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 256)  0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 384)  0           up_sampling2d[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 384)  1536        concatenate[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 384)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 256)  884992      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 256)  98560       concatenate[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 256)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 256)  1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 256)  590080      activation_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 32, 256)  0           batch_normalization_18[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 320)  0           up_sampling2d_1[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64, 64, 320)  1280        concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 320)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 128)  368768      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 64, 64, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 128)  41088       concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 128)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 64, 64, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 64, 128)  0           batch_normalization_21[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 128 0           add_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 160 0           up_sampling2d_2[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 128, 128, 160 640         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 128, 160 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 64) 92224       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 128, 128, 64) 256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 128, 64) 10304       concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 128, 128, 64) 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 128, 128, 64) 256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 64) 36928       activation_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 128, 128, 64) 0           batch_normalization_24[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 64) 0           add_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 80) 0           up_sampling2d_3[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 256, 256, 80) 320         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 256, 256, 80) 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 256, 256, 32) 23072       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 256, 256, 32) 128         conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 256, 256, 32) 2592        concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 256, 256, 32) 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 256, 256, 32) 128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 256, 256, 32) 9248        activation_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 256, 256, 32) 0           batch_normalization_27[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 256, 256, 1)  33          add_8[0][0]
# ==================================================================================================
# Total params: 4,723,057
# Trainable params: 4,715,761
# Non-trainable params: 7,296
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import  plot_model

plot_model(
    model,
    to_file="model.png",
    show_shapes=True,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=True,
    dpi=100,
)

# %% [markdown]
# # Loss
# # &
# # Compile

# %%
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def IOU(y_true, y_pred):

    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)

    thresh = 0.5

    y_true = K.cast(K.greater_equal(y_true, thresh), 'float32')
    y_pred = K.cast(K.greater_equal(y_pred, thresh), 'float32')

    union = K.sum(K.maximum(y_true, y_pred)) + K.epsilon()
    intersection = K.sum(K.minimum(y_true, y_pred)) + K.epsilon()

    iou = intersection/union

    return iou

# %%
def lr_schedule(epoch):

    lr =0.0035
    if epoch >150:
        lr *=2**-1
    elif epoch >80:
        lr *=2**(-1)
    elif epoch >50:
        lr *=2**(-1)
    elif epoch >30:
        lr *=2**(-1)
    
    print('Learning rate: ', lr)
    return lr

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import LearningRateScheduler
from keras.optimizers import SGD

# %%
import time

start_time = time.time()

# Prepare callbacks for model saving and for learning rate adjustment.
lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [lr_reducer, lr_scheduler]

# %%
import tensorflow as tf
optimiser=tf.keras.optimizers.Adam(
    learning_rate=lr_schedule(0),
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=True,
    name="Adam"
)
model.compile(optimizer =optimiser , loss = dice_coef_loss, metrics = ['accuracy', IOU, dice_coef])
# Out:
# Learning rate:  0.0035

# %% [markdown]
# # Training

# %%
train_steps = len(train_image_files)//batch_size
valid_steps = len(valid_image_files)//batch_size

history = model.fit(
    tg, 
    steps_per_epoch=train_steps,
    initial_epoch = 0,
    epochs=100,
    validation_data = vg,    
    validation_steps = valid_steps,callbacks=callbacks)
# Out:
# Learning rate:  0.0035
# Epoch 1/100
# 300/300 [==============================] - 29s 96ms/step - loss: 0.3741 - accuracy: 0.9495 - IOU: 0.4663 - dice_coef: 0.6259 - val_loss: 0.4396 - val_accuracy: 0.9484 - val_IOU: 0.4028 - val_dice_coef: 0.5604 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 2/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.3201 - accuracy: 0.9582 - IOU: 0.5236 - dice_coef: 0.6799 - val_loss: 0.3967 - val_accuracy: 0.9550 - val_IOU: 0.4493 - val_dice_coef: 0.6033 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 3/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.3133 - accuracy: 0.9595 - IOU: 0.5318 - dice_coef: 0.6867 - val_loss: 0.3578 - val_accuracy: 0.9400 - val_IOU: 0.4888 - val_dice_coef: 0.6422 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 4/100
# 300/300 [==============================] - 28s 95ms/step - loss: 0.2968 - accuracy: 0.9616 - IOU: 0.5497 - dice_coef: 0.7032 - val_loss: 0.5170 - val_accuracy: 0.8597 - val_IOU: 0.3309 - val_dice_coef: 0.4830 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 5/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2881 - accuracy: 0.9634 - IOU: 0.5603 - dice_coef: 0.7119 - val_loss: 0.2960 - val_accuracy: 0.9660 - val_IOU: 0.5502 - val_dice_coef: 0.7040 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 6/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2897 - accuracy: 0.9627 - IOU: 0.5582 - dice_coef: 0.7103 - val_loss: 0.2831 - val_accuracy: 0.9658 - val_IOU: 0.5674 - val_dice_coef: 0.7169 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 7/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2796 - accuracy: 0.9640 - IOU: 0.5700 - dice_coef: 0.7204 - val_loss: 0.2745 - val_accuracy: 0.9671 - val_IOU: 0.5759 - val_dice_coef: 0.7255 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 8/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2770 - accuracy: 0.9643 - IOU: 0.5734 - dice_coef: 0.7230 - val_loss: 0.3242 - val_accuracy: 0.9466 - val_IOU: 0.5209 - val_dice_coef: 0.6758 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 9/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2802 - accuracy: 0.9641 - IOU: 0.5699 - dice_coef: 0.7198 - val_loss: 0.3007 - val_accuracy: 0.9522 - val_IOU: 0.5493 - val_dice_coef: 0.6993 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 10/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2744 - accuracy: 0.9650 - IOU: 0.5764 - dice_coef: 0.7256 - val_loss: 0.2728 - val_accuracy: 0.9654 - val_IOU: 0.5777 - val_dice_coef: 0.7272 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 11/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2691 - accuracy: 0.9653 - IOU: 0.5825 - dice_coef: 0.7309 - val_loss: 0.2516 - val_accuracy: 0.9678 - val_IOU: 0.6026 - val_dice_coef: 0.7484 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 12/100
# 300/300 [==============================] - 28s 93ms/step - loss: 0.2648 - accuracy: 0.9663 - IOU: 0.5885 - dice_coef: 0.7352 - val_loss: 0.2642 - val_accuracy: 0.9647 - val_IOU: 0.5886 - val_dice_coef: 0.7358 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 13/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2633 - accuracy: 0.9661 - IOU: 0.5900 - dice_coef: 0.7367 - val_loss: 0.3014 - val_accuracy: 0.9629 - val_IOU: 0.5488 - val_dice_coef: 0.6986 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 14/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2600 - accuracy: 0.9668 - IOU: 0.5942 - dice_coef: 0.7400 - val_loss: 0.2777 - val_accuracy: 0.9681 - val_IOU: 0.5727 - val_dice_coef: 0.7223 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 15/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2661 - accuracy: 0.9663 - IOU: 0.5861 - dice_coef: 0.7339 - val_loss: 0.2761 - val_accuracy: 0.9655 - val_IOU: 0.5735 - val_dice_coef: 0.7239 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 16/100
# 300/300 [==============================] - 28s 95ms/step - loss: 0.2568 - accuracy: 0.9668 - IOU: 0.5976 - dice_coef: 0.7432 - val_loss: 0.2654 - val_accuracy: 0.9684 - val_IOU: 0.5864 - val_dice_coef: 0.7346 - lr: 0.0011
# Learning rate:  0.0035
# Epoch 17/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2563 - accuracy: 0.9671 - IOU: 0.5984 - dice_coef: 0.7437 - val_loss: 0.2479 - val_accuracy: 0.9696 - val_IOU: 0.6073 - val_dice_coef: 0.7521 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 18/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2594 - accuracy: 0.9665 - IOU: 0.5944 - dice_coef: 0.7406 - val_loss: 0.2701 - val_accuracy: 0.9627 - val_IOU: 0.5833 - val_dice_coef: 0.7299 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 19/100
# 300/300 [==============================] - 28s 93ms/step - loss: 0.2553 - accuracy: 0.9672 - IOU: 0.5999 - dice_coef: 0.7447 - val_loss: 0.2733 - val_accuracy: 0.9642 - val_IOU: 0.5783 - val_dice_coef: 0.7267 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 20/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2550 - accuracy: 0.9675 - IOU: 0.6004 - dice_coef: 0.7450 - val_loss: 0.2428 - val_accuracy: 0.9686 - val_IOU: 0.6138 - val_dice_coef: 0.7572 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 21/100
# 300/300 [==============================] - 28s 95ms/step - loss: 0.2523 - accuracy: 0.9674 - IOU: 0.6029 - dice_coef: 0.7477 - val_loss: 0.2570 - val_accuracy: 0.9657 - val_IOU: 0.5987 - val_dice_coef: 0.7430 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 22/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2555 - accuracy: 0.9677 - IOU: 0.6003 - dice_coef: 0.7445 - val_loss: 0.2428 - val_accuracy: 0.9678 - val_IOU: 0.6144 - val_dice_coef: 0.7572 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 23/100
# 300/300 [==============================] - 28s 95ms/step - loss: 0.2446 - accuracy: 0.9684 - IOU: 0.6127 - dice_coef: 0.7554 - val_loss: 0.2505 - val_accuracy: 0.9671 - val_IOU: 0.6052 - val_dice_coef: 0.7495 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 24/100
# 300/300 [==============================] - 29s 95ms/step - loss: 0.2504 - accuracy: 0.9677 - IOU: 0.6060 - dice_coef: 0.7496 - val_loss: 0.2525 - val_accuracy: 0.9692 - val_IOU: 0.6025 - val_dice_coef: 0.7475 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 25/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2511 - accuracy: 0.9677 - IOU: 0.6049 - dice_coef: 0.7489 - val_loss: 0.3411 - val_accuracy: 0.9476 - val_IOU: 0.5009 - val_dice_coef: 0.6589 - lr: 0.0011
# Learning rate:  0.0035
# Epoch 26/100
# 300/300 [==============================] - 29s 95ms/step - loss: 0.2517 - accuracy: 0.9679 - IOU: 0.6051 - dice_coef: 0.7483 - val_loss: 0.2570 - val_accuracy: 0.9657 - val_IOU: 0.5986 - val_dice_coef: 0.7430 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 27/100
# 300/300 [==============================] - 28s 95ms/step - loss: 0.2508 - accuracy: 0.9678 - IOU: 0.6061 - dice_coef: 0.7492 - val_loss: 0.2504 - val_accuracy: 0.9664 - val_IOU: 0.6060 - val_dice_coef: 0.7496 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 28/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2457 - accuracy: 0.9684 - IOU: 0.6119 - dice_coef: 0.7543 - val_loss: 0.2416 - val_accuracy: 0.9699 - val_IOU: 0.6158 - val_dice_coef: 0.7584 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 29/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2428 - accuracy: 0.9687 - IOU: 0.6153 - dice_coef: 0.7572 - val_loss: 0.2479 - val_accuracy: 0.9704 - val_IOU: 0.6087 - val_dice_coef: 0.7521 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 30/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2467 - accuracy: 0.9681 - IOU: 0.6111 - dice_coef: 0.7533 - val_loss: 0.2759 - val_accuracy: 0.9677 - val_IOU: 0.5750 - val_dice_coef: 0.7241 - lr: 0.0035
# Learning rate:  0.0035
# Epoch 31/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2438 - accuracy: 0.9687 - IOU: 0.6144 - dice_coef: 0.7562 - val_loss: 0.2559 - val_accuracy: 0.9660 - val_IOU: 0.6007 - val_dice_coef: 0.7441 - lr: 0.0035
# Learning rate:  0.00175
# Epoch 32/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2386 - accuracy: 0.9690 - IOU: 0.6208 - dice_coef: 0.7614 - val_loss: 0.2354 - val_accuracy: 0.9697 - val_IOU: 0.6237 - val_dice_coef: 0.7646 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 33/100
# 300/300 [==============================] - 29s 96ms/step - loss: 0.2376 - accuracy: 0.9694 - IOU: 0.6220 - dice_coef: 0.7624 - val_loss: 0.2359 - val_accuracy: 0.9704 - val_IOU: 0.6236 - val_dice_coef: 0.7641 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 34/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2409 - accuracy: 0.9689 - IOU: 0.6178 - dice_coef: 0.7591 - val_loss: 0.2387 - val_accuracy: 0.9711 - val_IOU: 0.6195 - val_dice_coef: 0.7613 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 35/100
# 300/300 [==============================] - 28s 95ms/step - loss: 0.2347 - accuracy: 0.9697 - IOU: 0.6256 - dice_coef: 0.7653 - val_loss: 0.2425 - val_accuracy: 0.9705 - val_IOU: 0.6153 - val_dice_coef: 0.7575 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 36/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2374 - accuracy: 0.9695 - IOU: 0.6221 - dice_coef: 0.7626 - val_loss: 0.2365 - val_accuracy: 0.9705 - val_IOU: 0.6224 - val_dice_coef: 0.7635 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 37/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2347 - accuracy: 0.9696 - IOU: 0.6253 - dice_coef: 0.7653 - val_loss: 0.2354 - val_accuracy: 0.9699 - val_IOU: 0.6237 - val_dice_coef: 0.7646 - lr: 5.5340e-04
# Learning rate:  0.00175
# Epoch 38/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2341 - accuracy: 0.9701 - IOU: 0.6265 - dice_coef: 0.7659 - val_loss: 0.2540 - val_accuracy: 0.9636 - val_IOU: 0.6032 - val_dice_coef: 0.7460 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 39/100
# 300/300 [==============================] - 29s 95ms/step - loss: 0.2361 - accuracy: 0.9697 - IOU: 0.6242 - dice_coef: 0.7639 - val_loss: 0.2349 - val_accuracy: 0.9693 - val_IOU: 0.6244 - val_dice_coef: 0.7651 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 40/100
# 300/300 [==============================] - 28s 95ms/step - loss: 0.2337 - accuracy: 0.9697 - IOU: 0.6267 - dice_coef: 0.7663 - val_loss: 0.2414 - val_accuracy: 0.9686 - val_IOU: 0.6155 - val_dice_coef: 0.7586 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 41/100
# 300/300 [==============================] - 28s 95ms/step - loss: 0.2332 - accuracy: 0.9700 - IOU: 0.6279 - dice_coef: 0.7668 - val_loss: 0.2335 - val_accuracy: 0.9695 - val_IOU: 0.6262 - val_dice_coef: 0.7665 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 42/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2367 - accuracy: 0.9695 - IOU: 0.6233 - dice_coef: 0.7633 - val_loss: 0.2497 - val_accuracy: 0.9693 - val_IOU: 0.6063 - val_dice_coef: 0.7503 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 43/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2369 - accuracy: 0.9696 - IOU: 0.6235 - dice_coef: 0.7631 - val_loss: 0.2321 - val_accuracy: 0.9702 - val_IOU: 0.6277 - val_dice_coef: 0.7679 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 44/100
# 300/300 [==============================] - 28s 95ms/step - loss: 0.2305 - accuracy: 0.9698 - IOU: 0.6308 - dice_coef: 0.7695 - val_loss: 0.2370 - val_accuracy: 0.9696 - val_IOU: 0.6217 - val_dice_coef: 0.7630 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 45/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2329 - accuracy: 0.9702 - IOU: 0.6283 - dice_coef: 0.7671 - val_loss: 0.2335 - val_accuracy: 0.9703 - val_IOU: 0.6262 - val_dice_coef: 0.7665 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 46/100
# 300/300 [==============================] - 28s 95ms/step - loss: 0.2322 - accuracy: 0.9699 - IOU: 0.6292 - dice_coef: 0.7678 - val_loss: 0.2350 - val_accuracy: 0.9693 - val_IOU: 0.6243 - val_dice_coef: 0.7650 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 47/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2319 - accuracy: 0.9700 - IOU: 0.6289 - dice_coef: 0.7681 - val_loss: 0.2345 - val_accuracy: 0.9686 - val_IOU: 0.6247 - val_dice_coef: 0.7655 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 48/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2351 - accuracy: 0.9695 - IOU: 0.6256 - dice_coef: 0.7649 - val_loss: 0.2322 - val_accuracy: 0.9707 - val_IOU: 0.6277 - val_dice_coef: 0.7678 - lr: 5.5340e-04
# Learning rate:  0.00175
# Epoch 49/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2309 - accuracy: 0.9702 - IOU: 0.6306 - dice_coef: 0.7691 - val_loss: 0.2417 - val_accuracy: 0.9700 - val_IOU: 0.6163 - val_dice_coef: 0.7583 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 50/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2307 - accuracy: 0.9702 - IOU: 0.6307 - dice_coef: 0.7693 - val_loss: 0.2348 - val_accuracy: 0.9695 - val_IOU: 0.6245 - val_dice_coef: 0.7652 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 51/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2303 - accuracy: 0.9702 - IOU: 0.6312 - dice_coef: 0.7697 - val_loss: 0.2498 - val_accuracy: 0.9705 - val_IOU: 0.6063 - val_dice_coef: 0.7502 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 52/100
# 300/300 [==============================] - 28s 95ms/step - loss: 0.2331 - accuracy: 0.9698 - IOU: 0.6280 - dice_coef: 0.7669 - val_loss: 0.2350 - val_accuracy: 0.9688 - val_IOU: 0.6245 - val_dice_coef: 0.7650 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 53/100
# 300/300 [==============================] - 28s 93ms/step - loss: 0.2296 - accuracy: 0.9704 - IOU: 0.6321 - dice_coef: 0.7704 - val_loss: 0.2326 - val_accuracy: 0.9693 - val_IOU: 0.6276 - val_dice_coef: 0.7674 - lr: 5.5340e-04
# Learning rate:  0.00175
# Epoch 54/100
# 300/300 [==============================] - 28s 93ms/step - loss: 0.2299 - accuracy: 0.9704 - IOU: 0.6316 - dice_coef: 0.7701 - val_loss: 0.2355 - val_accuracy: 0.9687 - val_IOU: 0.6237 - val_dice_coef: 0.7645 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 55/100
# 300/300 [==============================] - 28s 95ms/step - loss: 0.2279 - accuracy: 0.9706 - IOU: 0.6340 - dice_coef: 0.7721 - val_loss: 0.2444 - val_accuracy: 0.9682 - val_IOU: 0.6142 - val_dice_coef: 0.7556 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 56/100
# 300/300 [==============================] - 28s 93ms/step - loss: 0.2304 - accuracy: 0.9704 - IOU: 0.6316 - dice_coef: 0.7696 - val_loss: 0.2275 - val_accuracy: 0.9703 - val_IOU: 0.6334 - val_dice_coef: 0.7725 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 57/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2288 - accuracy: 0.9703 - IOU: 0.6329 - dice_coef: 0.7712 - val_loss: 0.2333 - val_accuracy: 0.9707 - val_IOU: 0.6264 - val_dice_coef: 0.7667 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 58/100
# 300/300 [==============================] - 28s 95ms/step - loss: 0.2313 - accuracy: 0.9700 - IOU: 0.6303 - dice_coef: 0.7687 - val_loss: 0.2306 - val_accuracy: 0.9707 - val_IOU: 0.6297 - val_dice_coef: 0.7694 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 59/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2301 - accuracy: 0.9705 - IOU: 0.6317 - dice_coef: 0.7699 - val_loss: 0.2310 - val_accuracy: 0.9693 - val_IOU: 0.6288 - val_dice_coef: 0.7690 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 60/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2288 - accuracy: 0.9706 - IOU: 0.6333 - dice_coef: 0.7712 - val_loss: 0.2351 - val_accuracy: 0.9691 - val_IOU: 0.6246 - val_dice_coef: 0.7649 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 61/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2318 - accuracy: 0.9702 - IOU: 0.6295 - dice_coef: 0.7682 - val_loss: 0.2376 - val_accuracy: 0.9699 - val_IOU: 0.6207 - val_dice_coef: 0.7624 - lr: 5.5340e-04
# Learning rate:  0.00175
# Epoch 62/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2289 - accuracy: 0.9704 - IOU: 0.6328 - dice_coef: 0.7711 - val_loss: 0.2281 - val_accuracy: 0.9707 - val_IOU: 0.6328 - val_dice_coef: 0.7719 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 63/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2283 - accuracy: 0.9703 - IOU: 0.6341 - dice_coef: 0.7717 - val_loss: 0.2292 - val_accuracy: 0.9703 - val_IOU: 0.6313 - val_dice_coef: 0.7708 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 64/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2309 - accuracy: 0.9702 - IOU: 0.6301 - dice_coef: 0.7691 - val_loss: 0.2322 - val_accuracy: 0.9704 - val_IOU: 0.6282 - val_dice_coef: 0.7678 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 65/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2321 - accuracy: 0.9701 - IOU: 0.6293 - dice_coef: 0.7679 - val_loss: 0.2482 - val_accuracy: 0.9661 - val_IOU: 0.6068 - val_dice_coef: 0.7518 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 66/100
# 300/300 [==============================] - 29s 95ms/step - loss: 0.2277 - accuracy: 0.9708 - IOU: 0.6346 - dice_coef: 0.7723 - val_loss: 0.2411 - val_accuracy: 0.9692 - val_IOU: 0.6175 - val_dice_coef: 0.7589 - lr: 5.5340e-04
# Learning rate:  0.00175
# Epoch 67/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2275 - accuracy: 0.9704 - IOU: 0.6346 - dice_coef: 0.7725 - val_loss: 0.2279 - val_accuracy: 0.9712 - val_IOU: 0.6329 - val_dice_coef: 0.7721 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 68/100
# 300/300 [==============================] - 28s 93ms/step - loss: 0.2269 - accuracy: 0.9708 - IOU: 0.6355 - dice_coef: 0.7731 - val_loss: 0.2420 - val_accuracy: 0.9703 - val_IOU: 0.6160 - val_dice_coef: 0.7580 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 69/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2314 - accuracy: 0.9702 - IOU: 0.6306 - dice_coef: 0.7686 - val_loss: 0.2439 - val_accuracy: 0.9663 - val_IOU: 0.6153 - val_dice_coef: 0.7561 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 70/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2316 - accuracy: 0.9701 - IOU: 0.6302 - dice_coef: 0.7684 - val_loss: 0.2338 - val_accuracy: 0.9705 - val_IOU: 0.6259 - val_dice_coef: 0.7662 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 71/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2282 - accuracy: 0.9704 - IOU: 0.6340 - dice_coef: 0.7718 - val_loss: 0.2260 - val_accuracy: 0.9718 - val_IOU: 0.6359 - val_dice_coef: 0.7740 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 72/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2317 - accuracy: 0.9703 - IOU: 0.6297 - dice_coef: 0.7683 - val_loss: 0.2377 - val_accuracy: 0.9691 - val_IOU: 0.6225 - val_dice_coef: 0.7623 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 73/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2291 - accuracy: 0.9704 - IOU: 0.6333 - dice_coef: 0.7709 - val_loss: 0.2276 - val_accuracy: 0.9712 - val_IOU: 0.6334 - val_dice_coef: 0.7724 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 74/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2303 - accuracy: 0.9707 - IOU: 0.6315 - dice_coef: 0.7697 - val_loss: 0.2305 - val_accuracy: 0.9711 - val_IOU: 0.6297 - val_dice_coef: 0.7695 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 75/100
# 300/300 [==============================] - 28s 93ms/step - loss: 0.2248 - accuracy: 0.9711 - IOU: 0.6381 - dice_coef: 0.7752 - val_loss: 0.2361 - val_accuracy: 0.9709 - val_IOU: 0.6231 - val_dice_coef: 0.7639 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 76/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2263 - accuracy: 0.9708 - IOU: 0.6360 - dice_coef: 0.7737 - val_loss: 0.2256 - val_accuracy: 0.9710 - val_IOU: 0.6357 - val_dice_coef: 0.7744 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 77/100
# 300/300 [==============================] - 28s 95ms/step - loss: 0.2269 - accuracy: 0.9709 - IOU: 0.6362 - dice_coef: 0.7731 - val_loss: 0.2256 - val_accuracy: 0.9711 - val_IOU: 0.6363 - val_dice_coef: 0.7744 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 78/100
# 300/300 [==============================] - 28s 93ms/step - loss: 0.2233 - accuracy: 0.9710 - IOU: 0.6399 - dice_coef: 0.7767 - val_loss: 0.2261 - val_accuracy: 0.9715 - val_IOU: 0.6353 - val_dice_coef: 0.7739 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 79/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2257 - accuracy: 0.9706 - IOU: 0.6370 - dice_coef: 0.7743 - val_loss: 0.2281 - val_accuracy: 0.9711 - val_IOU: 0.6330 - val_dice_coef: 0.7719 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 80/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2244 - accuracy: 0.9710 - IOU: 0.6390 - dice_coef: 0.7756 - val_loss: 0.2382 - val_accuracy: 0.9688 - val_IOU: 0.6218 - val_dice_coef: 0.7618 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 81/100
# 300/300 [==============================] - 28s 95ms/step - loss: 0.2285 - accuracy: 0.9707 - IOU: 0.6341 - dice_coef: 0.7715 - val_loss: 0.2348 - val_accuracy: 0.9687 - val_IOU: 0.6242 - val_dice_coef: 0.7652 - lr: 5.5340e-04
# Learning rate:  0.00175
# Epoch 82/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2253 - accuracy: 0.9708 - IOU: 0.6380 - dice_coef: 0.7747 - val_loss: 0.2465 - val_accuracy: 0.9664 - val_IOU: 0.6116 - val_dice_coef: 0.7535 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 83/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2253 - accuracy: 0.9711 - IOU: 0.6377 - dice_coef: 0.7747 - val_loss: 0.2305 - val_accuracy: 0.9704 - val_IOU: 0.6300 - val_dice_coef: 0.7695 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 84/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2269 - accuracy: 0.9708 - IOU: 0.6359 - dice_coef: 0.7731 - val_loss: 0.2304 - val_accuracy: 0.9699 - val_IOU: 0.6307 - val_dice_coef: 0.7696 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 85/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2243 - accuracy: 0.9709 - IOU: 0.6386 - dice_coef: 0.7757 - val_loss: 0.2265 - val_accuracy: 0.9714 - val_IOU: 0.6351 - val_dice_coef: 0.7735 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 86/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2226 - accuracy: 0.9711 - IOU: 0.6414 - dice_coef: 0.7774 - val_loss: 0.2354 - val_accuracy: 0.9688 - val_IOU: 0.6245 - val_dice_coef: 0.7646 - lr: 5.5340e-04
# Learning rate:  0.00175
# Epoch 87/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2233 - accuracy: 0.9710 - IOU: 0.6407 - dice_coef: 0.7767 - val_loss: 0.2285 - val_accuracy: 0.9707 - val_IOU: 0.6329 - val_dice_coef: 0.7715 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 88/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2246 - accuracy: 0.9710 - IOU: 0.6390 - dice_coef: 0.7754 - val_loss: 0.2441 - val_accuracy: 0.9681 - val_IOU: 0.6146 - val_dice_coef: 0.7559 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 89/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2224 - accuracy: 0.9712 - IOU: 0.6412 - dice_coef: 0.7776 - val_loss: 0.2247 - val_accuracy: 0.9716 - val_IOU: 0.6371 - val_dice_coef: 0.7753 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 90/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2231 - accuracy: 0.9714 - IOU: 0.6407 - dice_coef: 0.7769 - val_loss: 0.2302 - val_accuracy: 0.9703 - val_IOU: 0.6304 - val_dice_coef: 0.7698 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 91/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2259 - accuracy: 0.9707 - IOU: 0.6372 - dice_coef: 0.7741 - val_loss: 0.2267 - val_accuracy: 0.9704 - val_IOU: 0.6347 - val_dice_coef: 0.7733 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 92/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2244 - accuracy: 0.9709 - IOU: 0.6390 - dice_coef: 0.7756 - val_loss: 0.2264 - val_accuracy: 0.9713 - val_IOU: 0.6354 - val_dice_coef: 0.7736 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 93/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2265 - accuracy: 0.9705 - IOU: 0.6361 - dice_coef: 0.7735 - val_loss: 0.2310 - val_accuracy: 0.9707 - val_IOU: 0.6294 - val_dice_coef: 0.7690 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 94/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2248 - accuracy: 0.9709 - IOU: 0.6382 - dice_coef: 0.7752 - val_loss: 0.2322 - val_accuracy: 0.9701 - val_IOU: 0.6281 - val_dice_coef: 0.7678 - lr: 5.5340e-04
# Learning rate:  0.00175
# Epoch 95/100
# 300/300 [==============================] - 28s 94ms/step - loss: 0.2255 - accuracy: 0.9706 - IOU: 0.6377 - dice_coef: 0.7745 - val_loss: 0.2285 - val_accuracy: 0.9699 - val_IOU: 0.6326 - val_dice_coef: 0.7715 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 96/100
# 300/300 [==============================] - 28s 93ms/step - loss: 0.2229 - accuracy: 0.9711 - IOU: 0.6407 - dice_coef: 0.7771 - val_loss: 0.2277 - val_accuracy: 0.9701 - val_IOU: 0.6335 - val_dice_coef: 0.7723 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 97/100
# 300/300 [==============================] - 28s 92ms/step - loss: 0.2233 - accuracy: 0.9713 - IOU: 0.6402 - dice_coef: 0.7767 - val_loss: 0.2255 - val_accuracy: 0.9719 - val_IOU: 0.6362 - val_dice_coef: 0.7745 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 98/100
# 300/300 [==============================] - 28s 92ms/step - loss: 0.2253 - accuracy: 0.9709 - IOU: 0.6376 - dice_coef: 0.7747 - val_loss: 0.2537 - val_accuracy: 0.9634 - val_IOU: 0.6064 - val_dice_coef: 0.7463 - lr: 0.0018
# Learning rate:  0.00175
# Epoch 99/100
# 300/300 [==============================] - 28s 92ms/step - loss: 0.2220 - accuracy: 0.9715 - IOU: 0.6418 - dice_coef: 0.7780 - val_loss: 0.2314 - val_accuracy: 0.9705 - val_IOU: 0.6291 - val_dice_coef: 0.7686 - lr: 5.5340e-04
# Learning rate:  0.00175
# Epoch 100/100
# 300/300 [==============================] - 28s 92ms/step - loss: 0.2253 - accuracy: 0.9710 - IOU: 0.6379 - dice_coef: 0.7747 - val_loss: 0.2370 - val_accuracy: 0.9712 - val_IOU: 0.6220 - val_dice_coef: 0.7630 - lr: 0.0018

# %%
train_loss = history.history['loss']
valid_loss = history.history['val_loss']

train_acc = history.history['accuracy']
valid_acc = history.history['val_accuracy']

# %%
fig, axes = plt.subplots(1, 2, figsize=(13,4))
axes = axes.flatten()

axes[0].plot(train_acc, label='training')
axes[0].plot(valid_acc, label='validation')
axes[0].set_title('Accuracy Curve')
axes[0].set_xlabel('epochs')
axes[0].set_ylabel('accuracy')
axes[0].legend()


axes[1].plot(train_loss, label='training')
axes[1].plot(valid_loss, label='validation')
axes[1].set_title('Loss Curve')
axes[1].set_xlabel('epochs')
axes[1].set_ylabel('loss')
axes[1].legend()

plt.show()

# %%
train_dice = history.history['dice_coef']
valid_dice = history.history['val_dice_coef']


train_IOU = history.history['IOU']
valid_IOU = history.history['val_IOU']

# %%
fig, axes = plt.subplots(1, 2, figsize=(20,7))
axes = axes.flatten()

axes[0].plot(train_IOU, label='training')
axes[0].plot(valid_IOU, label='validation')
axes[0].set_title('IOU Curve [Adam lr : 0.0001]')
axes[0].set_xlabel('epochs')
axes[0].set_ylabel('IOU')
axes[0].legend()


axes[1].plot(train_dice, label='training')
axes[1].plot(valid_dice, label='validation')
axes[1].set_title('Dice coefficient Curve [Adam lr : 0.0001]')
axes[1].set_xlabel('epochs')
axes[1].set_ylabel('dice_coef')
axes[1].legend()

plt.show()

# %% [markdown]
# ## Testing

# %%
test_generator = Generator(valid_image_files, valid_mask_files, 396, img_dim)

for x_test, y_test in test_generator:
  break

y_pred = model.predict(x_test)

yy_true = (y_test>0.5).flatten()
yy_pred = (y_pred>0.5).flatten()

# %%
report = classification_report(yy_true, yy_pred, output_dict=True)

Accuracy = accuracy_score(yy_true, yy_pred)

Precision = report['True']['precision']
Recall = report['True']['recall']
F1_score = report['True']['f1-score']

Sensitivity = Recall
Specificity = report['False']['recall']

AUC = roc_auc_score(y_test.flatten(), y_pred.flatten())

IOU = (Precision*Recall)/(Precision+Recall-Precision*Recall)

print("Accuracy: {0:.4f}\n".format(Accuracy))
print("Precision: {0:.4f}\n".format(Precision))
print("Recall: {0:.4f}\n".format(Recall))
print("F1-Score: {0:.4f}\n".format(F1_score))
print("Sensitivity: {0:.4f}\n".format(Sensitivity))
print("Specificity: {0:.4f}\n".format(Specificity))
print("AUC: {0:.4f}\n".format(AUC))
print("IOU: {0:.4f}\n".format(IOU))
print('-'*50,'\n')
print(classification_report(yy_true, yy_pred))
# Out:
# Accuracy: 0.9712
#
# Precision: 0.8095
#
# Recall: 0.7409
#
# F1-Score: 0.7737
#
# Sensitivity: 0.7409
#
# Specificity: 0.9876
#
# AUC: 0.9053
#
# IOU: 0.6309
#
# --------------------------------------------------
#
#               precision    recall  f1-score   support
#
#        False       0.98      0.99      0.98  24228795
#         True       0.81      0.74      0.77   1723461
#
#     accuracy                           0.97  25952256
#    macro avg       0.90      0.86      0.88  25952256
# weighted avg       0.97      0.97      0.97  25952256

# %%
for i, j in test1_generator:
  break

print(i.shape)
print(j.shape)

# %%
ttg = Generator(test_image_paths,test_mask_paths, batch_size, img_dim, augment = False)

# %%
for i, j in ttg:
  break

print(i.shape)
print(j.shape)
# Out:
# (5, 256, 256, 3)
# (5, 256, 256, 1)

# %%
test_generator1 = Generator(test_image_paths,test_mask_paths,1124, img_dim)

for x_test, y_test in test_generator:
  break

y_pred = model.predict(x_test)

yy_true = (y_test>0.5).flatten()
yy_pred = (y_pred>0.5).flatten()

# %%
report = classification_report(yy_true, yy_pred, output_dict=True)

Accuracy = accuracy_score(yy_true, yy_pred)

Precision = report['True']['precision']
Recall = report['True']['recall']
F1_score = report['True']['f1-score']

Sensitivity = Recall
Specificity = report['False']['recall']

AUC = roc_auc_score(y_test.flatten(), y_pred.flatten())

IOU = (Precision*Recall)/(Precision+Recall-Precision*Recall)

print("Accuracy: {0:.4f}\n".format(Accuracy))
print("Precision: {0:.4f}\n".format(Precision))
print("Recall: {0:.4f}\n".format(Recall))
print("F1-Score: {0:.4f}\n".format(F1_score))
print("Sensitivity: {0:.4f}\n".format(Sensitivity))
print("Specificity: {0:.4f}\n".format(Specificity))
print("AUC: {0:.4f}\n".format(AUC))
print("IOU: {0:.4f}\n".format(IOU))
print('-'*50,'\n')
print(classification_report(yy_true, yy_pred))
# Out:
# Accuracy: 0.9712
#
# Precision: 0.8095
#
# Recall: 0.7409
#
# F1-Score: 0.7737
#
# Sensitivity: 0.7409
#
# Specificity: 0.9876
#
# AUC: 0.9053
#
# IOU: 0.6309
#
# --------------------------------------------------
#
#               precision    recall  f1-score   support
#
#        False       0.98      0.99      0.98  24228795
#         True       0.81      0.74      0.77   1723461
#
#     accuracy                           0.97  25952256
#    macro avg       0.90      0.86      0.88  25952256
# weighted avg       0.97      0.97      0.97  25952256
