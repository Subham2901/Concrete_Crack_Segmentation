# %% [markdown]
# ### Crack Segmentation on deep crack dataset.

# %% [markdown]
# ### Dataset = DEEP CRACK
# ### Optimiser=adam_and_beyond

# %% [markdown]
# ### Importing the neccessary libraries and mounting the google drive

# %%
! nvidia-smi
# Out:
# Mon Jul  6 22:01:17 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# %tensorflow_version 2.x

# %%
import os
import cv2
import shutil
import math
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import tensorflow as tf
from tensorflow import keras
import tensorflow.keras.backend as K
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Conv2DTranspose, Add, concatenate, average, Dropout
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score
from albumentations import Compose, OneOf, Flip, Rotate, RandomContrast, RandomGamma, RandomBrightness, ElasticTransform, GridDistortion, OpticalDistortion, RGBShift, CLAHE

# %%
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from skimage.transform import resize
from sklearn.metrics import classification_report

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Loading the dataset

# %%
import os
import zipfile
local_zip = '/content/drive/My Drive/Crack/DeepCrack.zip'

zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall()
zip_ref.close()
print("Done")
# Out:
# Done

# %% [markdown]
# ### Input Pipeline
# * The data is loaded with its respective masks
# * The data is then shuffled
# * Splited & Divided into train,test and validation sets

# %%
train_image_dir = r'/content/train_img'
train_mask_dir = r'/content/train_lab'

test_image_dir = r'/content/test_img'
test_mask_dir = r'/content/test_lab'

# %%
train_image_paths = sorted([os.path.join(train_image_dir, fname) for fname in os.listdir(train_image_dir) if fname.endswith(".jpg") and not fname.startswith(".")])
train_mask_paths = sorted([os.path.join(train_mask_dir, fname) for fname in os.listdir(train_mask_dir) if fname.endswith(".png") and not fname.startswith(".")])

test_image_paths = sorted([os.path.join(test_image_dir, fname) for fname in os.listdir(test_image_dir) if fname.endswith(".jpg") and not fname.startswith(".")])
test_mask_paths = sorted([os.path.join(test_mask_dir, fname) for fname in os.listdir(test_mask_dir) if fname.endswith(".png") and not fname.startswith(".")])

print("Number of training images : ", len(train_image_paths))
print("Number of training masks : ", len(train_mask_paths))
print('\n')
print("Number of testing images : ", len(test_image_paths))
print("Number of testing masks : ", len(test_mask_paths))
# Out:
# Number of training images :  300
# Number of training masks :  300
#
#
# Number of testing images :  237
# Number of testing masks :  237

# %%
# Shuffle
import random
combined = list(zip(train_image_paths, train_mask_paths))
random.shuffle(combined)

train_image_paths[:], train_mask_paths[:] = zip(*combined)

# %%
# Splitting
train_image_files = train_image_paths[:270]
train_mask_files = train_mask_paths[:270]

valid_image_files = train_image_paths[270:]
valid_mask_files = train_mask_paths[270:]

print(len(train_image_files), len(train_mask_files))
print(len(valid_image_files), len(valid_mask_files))
# Out:
# 270 270
# 30 30

# %% [markdown]
# ## Generator creation
# * A custom generator is created which combines the  image with its repective masks.
# * All data is augmented using albumentation library.
# * Random flips and rotations along with more attributes of the albumentation library are used to augment the images present in the training data

# %%
batch_size = 10
img_dim=(256, 256)

# %%
class Generator(Sequence):

  def __init__(self, x_set, y_set, batch_size=5, img_dim=(128, 128), augment=False):
      self.x = x_set
      self.y = y_set
      self.batch_size = batch_size
      self.img_dim = img_dim
      self.augment = augment

  def __len__(self):
      return math.ceil(len(self.x) / self.batch_size)

  augmentations = Compose(
    [                   
      Flip(p=0.7),
      Rotate(p=0.7),
      OneOf([
              RandomContrast(),
              RandomGamma(),
              RandomBrightness()
            ], p=0.3),
      OneOf([
              ElasticTransform(alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03),
              GridDistortion(),
              OpticalDistortion(distort_limit=2, shift_limit=0.5)
            ], p=0.3),
    ])

  def __getitem__(self, idx):
      batch_x = self.x[idx * self.batch_size:(idx + 1) * self.batch_size]
      batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]

      batch_x = np.array([cv2.resize(cv2.cvtColor(cv2.imread(file_name, -1), cv2.COLOR_BGR2RGB), (self.img_dim[1], self.img_dim[0])) for file_name in batch_x])
      batch_y = np.array([(cv2.resize(cv2.imread(file_name, -1), (self.img_dim[1], self.img_dim[0]))>0).astype(np.uint8) for file_name in batch_y])

      if self.augment is True:
        aug = [self.augmentations(image=i, mask=j) for i, j in zip(batch_x, batch_y)]
        batch_x = np.array([i['image'] for i in aug])
        batch_y = np.array([j['mask'] for j in aug])

      batch_y = np.expand_dims(batch_y, -1)

      return batch_x/255, batch_y/1

# %%
train_generator = Generator(train_image_files, train_mask_files)
validation_generator = Generator(valid_image_files, valid_mask_files)
test_generator=Generator(test_image_paths,test_mask_paths)

# %%
for i, j in train_generator:
  break

print(i.shape)
print(j.shape)
# Out:
# (5, 128, 128, 3)
# (5, 128, 128, 1)

# %%
for i, j in validation_generator:
  break

print(i.shape)
print(j.shape)
# Out:
# (5, 128, 128, 3)
# (5, 128, 128, 1)

# %%
for i,j in test_generator:
  break
print(i.shape)
print(j.shape)
# Out:
# (5, 128, 128, 3)
# (5, 128, 128, 1)

# %% [markdown]
# ### Plotting of the unaugmented images along with known images

# %%
# Train generator samples (Un-augmented)
for i, j in train_generator:
    break

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Images', fontsize=15)
axes = axes.flatten()
for img, ax in zip(i[:5], axes[:5]):
    ax.imshow(img)
    ax.axis('off')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Masks', fontsize=15)
axes = axes.flatten()
for img, ax in zip(j[:5], axes[:5]):
    ax.imshow(np.squeeze(img, -1), cmap='gray')
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
# Validation generator samples (Un-augmented)
for i, j in validation_generator:
    break

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Images', fontsize=15)
axes = axes.flatten()
for img, ax in zip(i[:5], axes[:5]):
    ax.imshow(img)
    ax.axis('off')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Masks', fontsize=15)
axes = axes.flatten()
for img, ax in zip(j[:5], axes[:5]):
    ax.imshow(np.squeeze(img, -1), cmap='gray')
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
# test generator samples (Un-augmented)
for i, j in test_generator:
    break

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Images', fontsize=15)
axes = axes.flatten()
for img, ax in zip(i[:5], axes[:5]):
    ax.imshow(img)
    ax.axis('off')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Original Masks', fontsize=15)
axes = axes.flatten()
for img, ax in zip(j[:5], axes[:5]):
    ax.imshow(np.squeeze(img, -1), cmap='gray')
    ax.axis('off')
plt.tight_layout()
plt.show()

# %%
tg = Generator(train_image_files, train_mask_files, batch_size, img_dim, augment = True)
vg = Generator(valid_image_files, valid_mask_files, batch_size, img_dim, augment = False)
testg=Generator(test_image_paths,test_mask_paths,batch_size,img_dim,augment=False)

# %%
for i, j in tg:
  break

print(i.shape)
print(j.shape)
# Out:
# (10, 256, 256, 3)
# (10, 256, 256, 1)

# %%
for i, j in vg:
  break

print(i.shape)
print(j.shape)
# Out:
# (10, 256, 256, 3)
# (10, 256, 256, 1)

# %%
for i, j in testg:
  break

print(i.shape)
print(j.shape)
# Out:
# (10, 256, 256, 3)
# (10, 256, 256, 1)

# %%
# Augmented train
for i, j in tg:
    break

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Augmented Images', fontsize=15)
axes = axes.flatten()
for img, ax in zip(i[:5], axes[:5]):
    ax.imshow(img)
    ax.axis('off')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 5, figsize=(13,2.5))
fig.suptitle('Augmented Masks', fontsize=15)
axes = axes.flatten()
for img, ax in zip(j[:5], axes[:5]):
    ax.imshow(np.squeeze(img, -1), cmap='gray')
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# #Model

# %%
import numpy as np
from tensorflow.keras.backend import int_shape
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Add, BatchNormalization, Input, Activation, Concatenate
from keras.regularizers import l2
# Out:
# Using TensorFlow backend.

# %%
# BatchNormalization and Activation
def BN_Act(x, act = True):
    x = BatchNormalization()(x)
    if act == True:
        x = Activation("relu")(x)
    return x

# %%
# conv2d block
def conv2d_block(x, filters, kernel_size = (3, 3), padding = "same", strides = 1):
    conv = BN_Act(x)
    conv = Conv2D(filters, kernel_size, padding = padding, strides = strides)(conv)
    return conv

# %%
# Fixed layer
def stem(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    conv = Conv2D(filters, kernel_size, padding = padding, strides = strides)(x)
    conv = conv2d_block(conv, filters, kernel_size = kernel_size, padding = padding, strides = strides)
    
    #skip
    shortcut = Conv2D(filters, kernel_size = (1, 1), padding = padding, strides = strides)(x)
    shortcut = BN_Act(shortcut, act = False) # No activation in skip connection
    
    output = Add()([conv, shortcut])
    return output

# %%
#Residual Block
def residual_block(x, filters, kernel_size = (3, 3), padding = "same", strides = 1):
    res = conv2d_block(x, filters, kernel_size = kernel_size, padding = padding, strides = strides)
    res = conv2d_block(res, filters, kernel_size = kernel_size, padding = padding, strides = 1)
    
    shortcut = Conv2D(filters, kernel_size = (1, 1), padding = padding, strides = strides)(x)
    shortcut = BN_Act(shortcut, act = False) # No activation in skip connection
    
    output = Add()([shortcut, res])
    return output

# %%
#Upsample concatenation block
def upsample_concat_block(x, xskip):
    u = UpSampling2D((2, 2))(x)
    c = Concatenate()([u, xskip])
    return c

# %%
# Complete model Architecture
def ResUNet():
    f = [16, 32, 64, 128, 256]
    inputs = Input((img_dim[0], img_dim[1], 3))
    
    ## Encoder/downsampling/contracting path
    e0 = inputs
    e1 = stem(e0, f[0])
    e2 = residual_block(e1, f[1], strides = 2)
    e3 = residual_block(e2, f[2], strides = 2)
    e4 = residual_block(e3, f[3], strides = 2)
    e5 = residual_block(e4, f[4], strides = 2)
    
    ## Bridge/Bottleneck
    b0 = conv2d_block(e5, f[4], strides = 1)
    b1 = conv2d_block(b0, f[4], strides = 1)
    
    ## Decoder/upsampling/expansive path
    u1 = upsample_concat_block(b1, e4)
    d1 = residual_block(u1, f[4])
    
    u2 = upsample_concat_block(d1, e3)
    d2 = residual_block(u2, f[3])
    
    u3 = upsample_concat_block(d2, e2)
    d3 = residual_block(u3, f[2])
    
    u4 = upsample_concat_block(d3, e1)
    d4 = residual_block(u4, f[1])
    
    outputs = Conv2D(1, (1, 1), padding = "same", activation = "sigmoid")(d4)
    model = Model(inputs, outputs)
    return model

# %%
K.clear_session()
model = ResUNet()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 16) 64          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 256, 256, 16) 0           conv2d_1[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256, 256, 16) 64          add[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 4640        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 32) 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 32) 544         add[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 32) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 32) 128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 32) 9248        activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 32) 0           batch_normalization_4[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 32) 128         add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 32) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 64)   18496       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 64)   2112        add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 64)   0           batch_normalization_7[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 128)  73856       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 128)  8320        add_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 128)  147584      activation_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 128)  0           batch_normalization_10[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 128)  512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 256)  295168      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 256)  33024       add_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 256)  590080      activation_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 256)  0           batch_normalization_13[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 256)  1024        add_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 256)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 256)  590080      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 256)  590080      activation_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 256)  0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 384)  0           up_sampling2d[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 384)  1536        concatenate[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 384)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 256)  884992      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 256)  98560       concatenate[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 256)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 256)  1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 256)  590080      activation_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 32, 256)  0           batch_normalization_18[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 320)  0           up_sampling2d_1[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64, 64, 320)  1280        concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 320)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 128)  368768      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 64, 64, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 128)  41088       concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 128)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 64, 64, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 64, 128)  0           batch_normalization_21[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 128 0           add_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 160 0           up_sampling2d_2[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 128, 128, 160 640         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 128, 160 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 64) 92224       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 128, 128, 64) 256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 128, 64) 10304       concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 128, 128, 64) 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 128, 128, 64) 256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 64) 36928       activation_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 128, 128, 64) 0           batch_normalization_24[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 64) 0           add_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 80) 0           up_sampling2d_3[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 256, 256, 80) 320         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 256, 256, 80) 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 256, 256, 32) 23072       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 256, 256, 32) 128         conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 256, 256, 32) 2592        concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 256, 256, 32) 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 256, 256, 32) 128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 256, 256, 32) 9248        activation_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 256, 256, 32) 0           batch_normalization_27[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 256, 256, 1)  33          add_8[0][0]
# ==================================================================================================
# Total params: 4,723,057
# Trainable params: 4,715,761
# Non-trainable params: 7,296
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import  plot_model

plot_model(
    model,
    to_file="model.png",
    show_shapes=True,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=True,
    dpi=100,
)

# %% [markdown]
# # Loss Function

# %%
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def IOU(y_true, y_pred):

    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)

    thresh = 0.5

    y_true = K.cast(K.greater_equal(y_true, thresh), 'float32')
    y_pred = K.cast(K.greater_equal(y_pred, thresh), 'float32')

    union = K.sum(K.maximum(y_true, y_pred)) + K.epsilon()
    intersection = K.sum(K.minimum(y_true, y_pred)) + K.epsilon()

    iou = intersection/union

    return iou

# def bce_dice_loss(y_true, y_pred):

#     return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

# %% [markdown]
# ### Learning Rate Schedular And other callbacks

# %%
def lr_schedule(epoch):
    lr =0.001
    if epoch >150:
        lr *=2**-1
    elif epoch >80:
        lr *=2**(-1)
    elif epoch >50:
        lr *=2**(-1)
    elif epoch >30:
        lr *=2**(-1)
    
    print('Learning rate: ', lr)
    return lr

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import LearningRateScheduler
from keras.optimizers import SGD

# %%
import time

start_time = time.time()

# Prepare callbacks for model saving and for learning rate adjustment.
lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-8)

callbacks = [lr_reducer, lr_scheduler]

# %% [markdown]
# ### Compiling with adam and beyond

# %%
import tensorflow as tf
learning_rate = 0.0035
optimiser=tf.keras.optimizers.Adam(
    learning_rate=lr_schedule(0),
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=True,
    name="Adam"
)
model.compile(optimizer =optimiser , loss = dice_coef_loss, metrics = ['accuracy', IOU, dice_coef])
# Out:
# Learning rate:  0.001

# %%
model.save('/content/drive/My Drive/Colab Notebooks/Adam_and_beyond.h5')

# %% [markdown]
# ## Training

# %%
train_steps = len(train_image_files)//batch_size
valid_steps = len(valid_image_files)//batch_size

history = model.fit(
    tg, 
    steps_per_epoch=train_steps,
    initial_epoch = 0,
    epochs=100,
    validation_data = vg,    
    validation_steps = valid_steps,callbacks=callbacks)
# Out:
# Learning rate:  0.001
# Epoch 1/100
# 27/27 [==============================] - 5s 188ms/step - loss: 0.4637 - accuracy: 0.9432 - IOU: 0.4225 - dice_coef: 0.5363 - val_loss: 0.9984 - val_accuracy: 0.9597 - val_IOU: 5.4432e-05 - val_dice_coef: 0.0016 - lr: 0.0010
# Learning rate:  0.001
# Epoch 2/100
# 27/27 [==============================] - 4s 156ms/step - loss: 0.2857 - accuracy: 0.9809 - IOU: 0.5645 - dice_coef: 0.7143 - val_loss: 0.9997 - val_accuracy: 0.9597 - val_IOU: 4.0180e-12 - val_dice_coef: 3.3443e-04 - lr: 0.0010
# Learning rate:  0.001
# Epoch 3/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.2755 - accuracy: 0.9819 - IOU: 0.5770 - dice_coef: 0.7245 - val_loss: 0.9727 - val_accuracy: 0.9597 - val_IOU: 0.0010 - val_dice_coef: 0.0273 - lr: 0.0010
# Learning rate:  0.001
# Epoch 4/100
# 27/27 [==============================] - 4s 158ms/step - loss: 0.2558 - accuracy: 0.9833 - IOU: 0.5991 - dice_coef: 0.7442 - val_loss: 0.9741 - val_accuracy: 0.9597 - val_IOU: 5.1128e-04 - val_dice_coef: 0.0259 - lr: 0.0010
# Learning rate:  0.001
# Epoch 5/100
# 27/27 [==============================] - 4s 160ms/step - loss: 0.2621 - accuracy: 0.9825 - IOU: 0.5929 - dice_coef: 0.7379 - val_loss: 0.9998 - val_accuracy: 0.9597 - val_IOU: 4.0180e-12 - val_dice_coef: 1.6617e-04 - lr: 0.0010
# Learning rate:  0.001
# Epoch 6/100
# 27/27 [==============================] - 4s 155ms/step - loss: 0.2399 - accuracy: 0.9842 - IOU: 0.6182 - dice_coef: 0.7601 - val_loss: 0.7214 - val_accuracy: 0.9668 - val_IOU: 0.2277 - val_dice_coef: 0.2786 - lr: 0.0010
# Learning rate:  0.001
# Epoch 7/100
# 27/27 [==============================] - 4s 162ms/step - loss: 0.2456 - accuracy: 0.9836 - IOU: 0.6114 - dice_coef: 0.7544 - val_loss: 0.9999 - val_accuracy: 0.9597 - val_IOU: 4.0180e-12 - val_dice_coef: 8.9405e-05 - lr: 0.0010
# Learning rate:  0.001
# Epoch 8/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.2266 - accuracy: 0.9849 - IOU: 0.6364 - dice_coef: 0.7734 - val_loss: 0.9983 - val_accuracy: 0.9597 - val_IOU: 5.3560e-04 - val_dice_coef: 0.0017 - lr: 0.0010
# Learning rate:  0.001
# Epoch 9/100
# 27/27 [==============================] - 4s 154ms/step - loss: 0.2244 - accuracy: 0.9854 - IOU: 0.6374 - dice_coef: 0.7756 - val_loss: 0.9869 - val_accuracy: 0.9598 - val_IOU: 0.0056 - val_dice_coef: 0.0131 - lr: 0.0010
# Learning rate:  0.001
# Epoch 10/100
# 27/27 [==============================] - 4s 151ms/step - loss: 0.2120 - accuracy: 0.9861 - IOU: 0.6546 - dice_coef: 0.7880 - val_loss: 0.9772 - val_accuracy: 0.9600 - val_IOU: 0.0104 - val_dice_coef: 0.0228 - lr: 0.0010
# Learning rate:  0.001
# Epoch 11/100
# 27/27 [==============================] - 4s 158ms/step - loss: 0.2138 - accuracy: 0.9856 - IOU: 0.6522 - dice_coef: 0.7862 - val_loss: 0.9823 - val_accuracy: 0.9599 - val_IOU: 0.0073 - val_dice_coef: 0.0177 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 12/100
# 27/27 [==============================] - 4s 160ms/step - loss: 0.2241 - accuracy: 0.9851 - IOU: 0.6407 - dice_coef: 0.7759 - val_loss: 0.9997 - val_accuracy: 0.9597 - val_IOU: 4.0180e-12 - val_dice_coef: 2.7083e-04 - lr: 0.0010
# Learning rate:  0.001
# Epoch 13/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.2320 - accuracy: 0.9843 - IOU: 0.6292 - dice_coef: 0.7680 - val_loss: 0.9239 - val_accuracy: 0.9611 - val_IOU: 0.0390 - val_dice_coef: 0.0761 - lr: 0.0010
# Learning rate:  0.001
# Epoch 14/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.2142 - accuracy: 0.9857 - IOU: 0.6520 - dice_coef: 0.7858 - val_loss: 0.7233 - val_accuracy: 0.9651 - val_IOU: 0.1590 - val_dice_coef: 0.2767 - lr: 0.0010
# Learning rate:  0.001
# Epoch 15/100
# 27/27 [==============================] - 4s 159ms/step - loss: 0.2313 - accuracy: 0.9845 - IOU: 0.6301 - dice_coef: 0.7687 - val_loss: 0.9335 - val_accuracy: 0.9608 - val_IOU: 0.0330 - val_dice_coef: 0.0665 - lr: 0.0010
# Learning rate:  0.001
# Epoch 16/100
# 27/27 [==============================] - 4s 159ms/step - loss: 0.2165 - accuracy: 0.9855 - IOU: 0.6487 - dice_coef: 0.7835 - val_loss: 0.6021 - val_accuracy: 0.9688 - val_IOU: 0.2437 - val_dice_coef: 0.3979 - lr: 0.0010
# Learning rate:  0.001
# Epoch 17/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.2000 - accuracy: 0.9868 - IOU: 0.6700 - dice_coef: 0.8000 - val_loss: 0.6110 - val_accuracy: 0.9679 - val_IOU: 0.2396 - val_dice_coef: 0.3890 - lr: 0.0010
# Learning rate:  0.001
# Epoch 18/100
# 27/27 [==============================] - 4s 150ms/step - loss: 0.1944 - accuracy: 0.9870 - IOU: 0.6774 - dice_coef: 0.8056 - val_loss: 0.4400 - val_accuracy: 0.9739 - val_IOU: 0.3924 - val_dice_coef: 0.5600 - lr: 0.0010
# Learning rate:  0.001
# Epoch 19/100
# 27/27 [==============================] - 4s 154ms/step - loss: 0.1960 - accuracy: 0.9871 - IOU: 0.6753 - dice_coef: 0.8040 - val_loss: 0.3027 - val_accuracy: 0.9805 - val_IOU: 0.5377 - val_dice_coef: 0.6973 - lr: 0.0010
# Learning rate:  0.001
# Epoch 20/100
# 27/27 [==============================] - 4s 159ms/step - loss: 0.1909 - accuracy: 0.9874 - IOU: 0.6825 - dice_coef: 0.8091 - val_loss: 0.2698 - val_accuracy: 0.9813 - val_IOU: 0.5781 - val_dice_coef: 0.7302 - lr: 0.0010
# Learning rate:  0.001
# Epoch 21/100
# 27/27 [==============================] - 4s 153ms/step - loss: 0.1884 - accuracy: 0.9874 - IOU: 0.6857 - dice_coef: 0.8116 - val_loss: 0.3526 - val_accuracy: 0.9781 - val_IOU: 0.4830 - val_dice_coef: 0.6474 - lr: 0.0010
# Learning rate:  0.001
# Epoch 22/100
# 27/27 [==============================] - 4s 156ms/step - loss: 0.1872 - accuracy: 0.9874 - IOU: 0.6876 - dice_coef: 0.8128 - val_loss: 0.1987 - val_accuracy: 0.9857 - val_IOU: 0.6706 - val_dice_coef: 0.8013 - lr: 0.0010
# Learning rate:  0.001
# Epoch 23/100
# 27/27 [==============================] - 4s 158ms/step - loss: 0.1891 - accuracy: 0.9873 - IOU: 0.6856 - dice_coef: 0.8109 - val_loss: 0.2035 - val_accuracy: 0.9853 - val_IOU: 0.6636 - val_dice_coef: 0.7965 - lr: 0.0010
# Learning rate:  0.001
# Epoch 24/100
# 27/27 [==============================] - 4s 158ms/step - loss: 0.1803 - accuracy: 0.9879 - IOU: 0.6972 - dice_coef: 0.8197 - val_loss: 0.3197 - val_accuracy: 0.9802 - val_IOU: 0.5208 - val_dice_coef: 0.6803 - lr: 0.0010
# Learning rate:  0.001
# Epoch 25/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.1936 - accuracy: 0.9869 - IOU: 0.6786 - dice_coef: 0.8064 - val_loss: 0.1892 - val_accuracy: 0.9861 - val_IOU: 0.6839 - val_dice_coef: 0.8108 - lr: 0.0010
# Learning rate:  0.001
# Epoch 26/100
# 27/27 [==============================] - 4s 164ms/step - loss: 0.1957 - accuracy: 0.9872 - IOU: 0.6769 - dice_coef: 0.8043 - val_loss: 0.1750 - val_accuracy: 0.9875 - val_IOU: 0.7046 - val_dice_coef: 0.8250 - lr: 0.0010
# Learning rate:  0.001
# Epoch 27/100
# 27/27 [==============================] - 4s 159ms/step - loss: 0.1895 - accuracy: 0.9871 - IOU: 0.6847 - dice_coef: 0.8105 - val_loss: 0.1617 - val_accuracy: 0.9874 - val_IOU: 0.7238 - val_dice_coef: 0.8383 - lr: 0.0010
# Learning rate:  0.001
# Epoch 28/100
# 27/27 [==============================] - 4s 159ms/step - loss: 0.1860 - accuracy: 0.9876 - IOU: 0.6888 - dice_coef: 0.8140 - val_loss: 0.2025 - val_accuracy: 0.9856 - val_IOU: 0.6651 - val_dice_coef: 0.7975 - lr: 0.0010
# Learning rate:  0.001
# Epoch 29/100
# 27/27 [==============================] - 5s 168ms/step - loss: 0.1783 - accuracy: 0.9880 - IOU: 0.7000 - dice_coef: 0.8217 - val_loss: 0.1879 - val_accuracy: 0.9835 - val_IOU: 0.6874 - val_dice_coef: 0.8121 - lr: 0.0010
# Learning rate:  0.001
# Epoch 30/100
# 27/27 [==============================] - 4s 162ms/step - loss: 0.1839 - accuracy: 0.9875 - IOU: 0.6922 - dice_coef: 0.8161 - val_loss: 0.1666 - val_accuracy: 0.9872 - val_IOU: 0.7181 - val_dice_coef: 0.8334 - lr: 0.0010
# Learning rate:  0.001
# Epoch 31/100
# 27/27 [==============================] - 4s 155ms/step - loss: 0.1856 - accuracy: 0.9875 - IOU: 0.6901 - dice_coef: 0.8144 - val_loss: 0.1637 - val_accuracy: 0.9871 - val_IOU: 0.7212 - val_dice_coef: 0.8363 - lr: 0.0010
# Learning rate:  0.0005
# Epoch 32/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.1876 - accuracy: 0.9874 - IOU: 0.6886 - dice_coef: 0.8124 - val_loss: 0.1968 - val_accuracy: 0.9855 - val_IOU: 0.6732 - val_dice_coef: 0.8032 - lr: 1.5811e-04
# Learning rate:  0.0005
# Epoch 33/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.1800 - accuracy: 0.9881 - IOU: 0.6979 - dice_coef: 0.8200 - val_loss: 0.1812 - val_accuracy: 0.9869 - val_IOU: 0.6947 - val_dice_coef: 0.8188 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 34/100
# 27/27 [==============================] - 4s 156ms/step - loss: 0.1781 - accuracy: 0.9882 - IOU: 0.7002 - dice_coef: 0.8219 - val_loss: 0.1912 - val_accuracy: 0.9865 - val_IOU: 0.6806 - val_dice_coef: 0.8088 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 35/100
# 27/27 [==============================] - 4s 154ms/step - loss: 0.1697 - accuracy: 0.9887 - IOU: 0.7123 - dice_coef: 0.8303 - val_loss: 0.1591 - val_accuracy: 0.9874 - val_IOU: 0.7284 - val_dice_coef: 0.8409 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 36/100
# 27/27 [==============================] - 4s 154ms/step - loss: 0.1742 - accuracy: 0.9882 - IOU: 0.7057 - dice_coef: 0.8258 - val_loss: 0.1724 - val_accuracy: 0.9872 - val_IOU: 0.7077 - val_dice_coef: 0.8276 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 37/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.1768 - accuracy: 0.9881 - IOU: 0.7021 - dice_coef: 0.8232 - val_loss: 0.1475 - val_accuracy: 0.9887 - val_IOU: 0.7453 - val_dice_coef: 0.8525 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 38/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.1716 - accuracy: 0.9886 - IOU: 0.7094 - dice_coef: 0.8284 - val_loss: 0.1496 - val_accuracy: 0.9883 - val_IOU: 0.7422 - val_dice_coef: 0.8504 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 39/100
# 27/27 [==============================] - 4s 159ms/step - loss: 0.1668 - accuracy: 0.9890 - IOU: 0.7164 - dice_coef: 0.8332 - val_loss: 0.1408 - val_accuracy: 0.9893 - val_IOU: 0.7555 - val_dice_coef: 0.8592 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 40/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.1661 - accuracy: 0.9888 - IOU: 0.7172 - dice_coef: 0.8339 - val_loss: 0.1447 - val_accuracy: 0.9890 - val_IOU: 0.7494 - val_dice_coef: 0.8553 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 41/100
# 27/27 [==============================] - 4s 161ms/step - loss: 0.1677 - accuracy: 0.9886 - IOU: 0.7154 - dice_coef: 0.8323 - val_loss: 0.1575 - val_accuracy: 0.9886 - val_IOU: 0.7299 - val_dice_coef: 0.8425 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 42/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.1651 - accuracy: 0.9888 - IOU: 0.7188 - dice_coef: 0.8349 - val_loss: 0.1431 - val_accuracy: 0.9893 - val_IOU: 0.7518 - val_dice_coef: 0.8569 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 43/100
# 27/27 [==============================] - 4s 156ms/step - loss: 0.1630 - accuracy: 0.9891 - IOU: 0.7217 - dice_coef: 0.8370 - val_loss: 0.1345 - val_accuracy: 0.9898 - val_IOU: 0.7648 - val_dice_coef: 0.8655 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 44/100
# 27/27 [==============================] - 4s 155ms/step - loss: 0.1618 - accuracy: 0.9892 - IOU: 0.7236 - dice_coef: 0.8382 - val_loss: 0.1625 - val_accuracy: 0.9878 - val_IOU: 0.7213 - val_dice_coef: 0.8375 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 45/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.1749 - accuracy: 0.9880 - IOU: 0.7051 - dice_coef: 0.8251 - val_loss: 0.1394 - val_accuracy: 0.9892 - val_IOU: 0.7573 - val_dice_coef: 0.8606 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 46/100
# 27/27 [==============================] - 4s 160ms/step - loss: 0.1709 - accuracy: 0.9886 - IOU: 0.7106 - dice_coef: 0.8291 - val_loss: 0.1382 - val_accuracy: 0.9894 - val_IOU: 0.7597 - val_dice_coef: 0.8618 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 47/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.1666 - accuracy: 0.9889 - IOU: 0.7166 - dice_coef: 0.8334 - val_loss: 0.1414 - val_accuracy: 0.9893 - val_IOU: 0.7540 - val_dice_coef: 0.8586 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 48/100
# 27/27 [==============================] - 4s 159ms/step - loss: 0.1675 - accuracy: 0.9887 - IOU: 0.7159 - dice_coef: 0.8325 - val_loss: 0.1375 - val_accuracy: 0.9897 - val_IOU: 0.7606 - val_dice_coef: 0.8625 - lr: 1.5811e-04
# Learning rate:  0.0005
# Epoch 49/100
# 27/27 [==============================] - 4s 154ms/step - loss: 0.1688 - accuracy: 0.9884 - IOU: 0.7144 - dice_coef: 0.8312 - val_loss: 0.1467 - val_accuracy: 0.9888 - val_IOU: 0.7463 - val_dice_coef: 0.8533 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 50/100
# 27/27 [==============================] - 4s 155ms/step - loss: 0.1652 - accuracy: 0.9891 - IOU: 0.7189 - dice_coef: 0.8348 - val_loss: 0.1353 - val_accuracy: 0.9896 - val_IOU: 0.7642 - val_dice_coef: 0.8647 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 51/100
# 27/27 [==============================] - 4s 160ms/step - loss: 0.1620 - accuracy: 0.9892 - IOU: 0.7231 - dice_coef: 0.8380 - val_loss: 0.1402 - val_accuracy: 0.9895 - val_IOU: 0.7561 - val_dice_coef: 0.8598 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 52/100
# 27/27 [==============================] - 4s 156ms/step - loss: 0.1599 - accuracy: 0.9893 - IOU: 0.7264 - dice_coef: 0.8401 - val_loss: 0.1554 - val_accuracy: 0.9886 - val_IOU: 0.7333 - val_dice_coef: 0.8446 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 53/100
# 27/27 [==============================] - 4s 162ms/step - loss: 0.1638 - accuracy: 0.9889 - IOU: 0.7208 - dice_coef: 0.8362 - val_loss: 0.1403 - val_accuracy: 0.9890 - val_IOU: 0.7563 - val_dice_coef: 0.8597 - lr: 1.5811e-04
# Learning rate:  0.0005
# Epoch 54/100
# 27/27 [==============================] - 4s 155ms/step - loss: 0.1625 - accuracy: 0.9891 - IOU: 0.7226 - dice_coef: 0.8375 - val_loss: 0.1491 - val_accuracy: 0.9887 - val_IOU: 0.7418 - val_dice_coef: 0.8509 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 55/100
# 27/27 [==============================] - 4s 155ms/step - loss: 0.1632 - accuracy: 0.9891 - IOU: 0.7215 - dice_coef: 0.8368 - val_loss: 0.1333 - val_accuracy: 0.9899 - val_IOU: 0.7666 - val_dice_coef: 0.8667 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 56/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.1572 - accuracy: 0.9893 - IOU: 0.7306 - dice_coef: 0.8428 - val_loss: 0.1418 - val_accuracy: 0.9895 - val_IOU: 0.7531 - val_dice_coef: 0.8582 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 57/100
# 27/27 [==============================] - 4s 159ms/step - loss: 0.1638 - accuracy: 0.9893 - IOU: 0.7213 - dice_coef: 0.8362 - val_loss: 0.1360 - val_accuracy: 0.9892 - val_IOU: 0.7626 - val_dice_coef: 0.8640 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 58/100
# 27/27 [==============================] - 4s 159ms/step - loss: 0.1603 - accuracy: 0.9892 - IOU: 0.7258 - dice_coef: 0.8397 - val_loss: 0.1303 - val_accuracy: 0.9900 - val_IOU: 0.7716 - val_dice_coef: 0.8697 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 59/100
# 27/27 [==============================] - 4s 158ms/step - loss: 0.1568 - accuracy: 0.9894 - IOU: 0.7311 - dice_coef: 0.8432 - val_loss: 0.1486 - val_accuracy: 0.9881 - val_IOU: 0.7438 - val_dice_coef: 0.8514 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 60/100
# 27/27 [==============================] - 4s 158ms/step - loss: 0.1583 - accuracy: 0.9894 - IOU: 0.7289 - dice_coef: 0.8417 - val_loss: 0.1510 - val_accuracy: 0.9888 - val_IOU: 0.7398 - val_dice_coef: 0.8490 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 61/100
# 27/27 [==============================] - 5s 168ms/step - loss: 0.1666 - accuracy: 0.9891 - IOU: 0.7161 - dice_coef: 0.8334 - val_loss: 0.1334 - val_accuracy: 0.9896 - val_IOU: 0.7664 - val_dice_coef: 0.8666 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 62/100
# 27/27 [==============================] - 4s 158ms/step - loss: 0.1676 - accuracy: 0.9888 - IOU: 0.7151 - dice_coef: 0.8324 - val_loss: 0.1454 - val_accuracy: 0.9883 - val_IOU: 0.7487 - val_dice_coef: 0.8546 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 63/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.1667 - accuracy: 0.9888 - IOU: 0.7164 - dice_coef: 0.8333 - val_loss: 0.1405 - val_accuracy: 0.9896 - val_IOU: 0.7552 - val_dice_coef: 0.8595 - lr: 1.5811e-04
# Learning rate:  0.0005
# Epoch 64/100
# 27/27 [==============================] - 4s 154ms/step - loss: 0.1565 - accuracy: 0.9894 - IOU: 0.7314 - dice_coef: 0.8435 - val_loss: 0.1360 - val_accuracy: 0.9896 - val_IOU: 0.7623 - val_dice_coef: 0.8640 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 65/100
# 27/27 [==============================] - 4s 159ms/step - loss: 0.1564 - accuracy: 0.9896 - IOU: 0.7316 - dice_coef: 0.8436 - val_loss: 0.1364 - val_accuracy: 0.9899 - val_IOU: 0.7617 - val_dice_coef: 0.8636 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 66/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.1627 - accuracy: 0.9890 - IOU: 0.7227 - dice_coef: 0.8373 - val_loss: 0.1385 - val_accuracy: 0.9895 - val_IOU: 0.7582 - val_dice_coef: 0.8615 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 67/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.1539 - accuracy: 0.9896 - IOU: 0.7349 - dice_coef: 0.8461 - val_loss: 0.1311 - val_accuracy: 0.9898 - val_IOU: 0.7700 - val_dice_coef: 0.8689 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 68/100
# 27/27 [==============================] - 4s 160ms/step - loss: 0.1600 - accuracy: 0.9893 - IOU: 0.7263 - dice_coef: 0.8400 - val_loss: 0.1294 - val_accuracy: 0.9902 - val_IOU: 0.7728 - val_dice_coef: 0.8706 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 69/100
# 27/27 [==============================] - 4s 155ms/step - loss: 0.1613 - accuracy: 0.9894 - IOU: 0.7241 - dice_coef: 0.8387 - val_loss: 0.1324 - val_accuracy: 0.9899 - val_IOU: 0.7677 - val_dice_coef: 0.8676 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 70/100
# 27/27 [==============================] - 4s 155ms/step - loss: 0.1526 - accuracy: 0.9898 - IOU: 0.7373 - dice_coef: 0.8474 - val_loss: 0.1358 - val_accuracy: 0.9897 - val_IOU: 0.7622 - val_dice_coef: 0.8642 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 71/100
# 27/27 [==============================] - 4s 161ms/step - loss: 0.1584 - accuracy: 0.9893 - IOU: 0.7287 - dice_coef: 0.8416 - val_loss: 0.1548 - val_accuracy: 0.9885 - val_IOU: 0.7338 - val_dice_coef: 0.8452 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 72/100
# 27/27 [==============================] - 4s 154ms/step - loss: 0.1548 - accuracy: 0.9897 - IOU: 0.7337 - dice_coef: 0.8452 - val_loss: 0.1339 - val_accuracy: 0.9894 - val_IOU: 0.7656 - val_dice_coef: 0.8661 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 73/100
# 27/27 [==============================] - 4s 152ms/step - loss: 0.1552 - accuracy: 0.9896 - IOU: 0.7328 - dice_coef: 0.8448 - val_loss: 0.1441 - val_accuracy: 0.9895 - val_IOU: 0.7498 - val_dice_coef: 0.8559 - lr: 1.5811e-04
# Learning rate:  0.0005
# Epoch 74/100
# 27/27 [==============================] - 4s 160ms/step - loss: 0.1533 - accuracy: 0.9898 - IOU: 0.7359 - dice_coef: 0.8467 - val_loss: 0.1336 - val_accuracy: 0.9893 - val_IOU: 0.7659 - val_dice_coef: 0.8664 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 75/100
# 27/27 [==============================] - 4s 162ms/step - loss: 0.1524 - accuracy: 0.9898 - IOU: 0.7371 - dice_coef: 0.8476 - val_loss: 0.1281 - val_accuracy: 0.9902 - val_IOU: 0.7746 - val_dice_coef: 0.8719 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 76/100
# 27/27 [==============================] - 4s 162ms/step - loss: 0.1578 - accuracy: 0.9894 - IOU: 0.7297 - dice_coef: 0.8422 - val_loss: 0.1290 - val_accuracy: 0.9899 - val_IOU: 0.7737 - val_dice_coef: 0.8710 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 77/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.1572 - accuracy: 0.9894 - IOU: 0.7304 - dice_coef: 0.8428 - val_loss: 0.1352 - val_accuracy: 0.9897 - val_IOU: 0.7632 - val_dice_coef: 0.8648 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 78/100
# 27/27 [==============================] - 4s 154ms/step - loss: 0.1603 - accuracy: 0.9892 - IOU: 0.7257 - dice_coef: 0.8397 - val_loss: 0.1614 - val_accuracy: 0.9886 - val_IOU: 0.7260 - val_dice_coef: 0.8386 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 79/100
# 27/27 [==============================] - 4s 154ms/step - loss: 0.1539 - accuracy: 0.9897 - IOU: 0.7352 - dice_coef: 0.8461 - val_loss: 0.1578 - val_accuracy: 0.9884 - val_IOU: 0.7302 - val_dice_coef: 0.8422 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 80/100
# 27/27 [==============================] - 4s 159ms/step - loss: 0.1550 - accuracy: 0.9896 - IOU: 0.7337 - dice_coef: 0.8450 - val_loss: 0.1279 - val_accuracy: 0.9900 - val_IOU: 0.7749 - val_dice_coef: 0.8721 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 81/100
# 27/27 [==============================] - 4s 153ms/step - loss: 0.1503 - accuracy: 0.9900 - IOU: 0.7409 - dice_coef: 0.8497 - val_loss: 0.1292 - val_accuracy: 0.9901 - val_IOU: 0.7734 - val_dice_coef: 0.8708 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 82/100
# 27/27 [==============================] - 4s 153ms/step - loss: 0.1530 - accuracy: 0.9897 - IOU: 0.7370 - dice_coef: 0.8470 - val_loss: 0.1299 - val_accuracy: 0.9901 - val_IOU: 0.7725 - val_dice_coef: 0.8701 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 83/100
# 27/27 [==============================] - 4s 150ms/step - loss: 0.1512 - accuracy: 0.9899 - IOU: 0.7391 - dice_coef: 0.8488 - val_loss: 0.1303 - val_accuracy: 0.9898 - val_IOU: 0.7705 - val_dice_coef: 0.8697 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 84/100
# 27/27 [==============================] - 4s 161ms/step - loss: 0.1553 - accuracy: 0.9893 - IOU: 0.7331 - dice_coef: 0.8447 - val_loss: 0.1332 - val_accuracy: 0.9897 - val_IOU: 0.7668 - val_dice_coef: 0.8668 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 85/100
# 27/27 [==============================] - 4s 155ms/step - loss: 0.1542 - accuracy: 0.9898 - IOU: 0.7347 - dice_coef: 0.8458 - val_loss: 0.1381 - val_accuracy: 0.9897 - val_IOU: 0.7589 - val_dice_coef: 0.8619 - lr: 1.5811e-04
# Learning rate:  0.0005
# Epoch 86/100
# 27/27 [==============================] - 4s 158ms/step - loss: 0.1508 - accuracy: 0.9898 - IOU: 0.7398 - dice_coef: 0.8492 - val_loss: 0.1369 - val_accuracy: 0.9888 - val_IOU: 0.7616 - val_dice_coef: 0.8631 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 87/100
# 27/27 [==============================] - 4s 156ms/step - loss: 0.1509 - accuracy: 0.9898 - IOU: 0.7394 - dice_coef: 0.8491 - val_loss: 0.1360 - val_accuracy: 0.9899 - val_IOU: 0.7619 - val_dice_coef: 0.8640 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 88/100
# 27/27 [==============================] - 4s 153ms/step - loss: 0.1541 - accuracy: 0.9894 - IOU: 0.7347 - dice_coef: 0.8459 - val_loss: 0.1310 - val_accuracy: 0.9897 - val_IOU: 0.7707 - val_dice_coef: 0.8690 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 89/100
# 27/27 [==============================] - 4s 159ms/step - loss: 0.1531 - accuracy: 0.9899 - IOU: 0.7362 - dice_coef: 0.8469 - val_loss: 0.1304 - val_accuracy: 0.9901 - val_IOU: 0.7708 - val_dice_coef: 0.8696 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 90/100
# 27/27 [==============================] - 4s 153ms/step - loss: 0.1497 - accuracy: 0.9898 - IOU: 0.7410 - dice_coef: 0.8503 - val_loss: 0.1438 - val_accuracy: 0.9880 - val_IOU: 0.7503 - val_dice_coef: 0.8562 - lr: 1.5811e-04
# Learning rate:  0.0005
# Epoch 91/100
# 27/27 [==============================] - 4s 152ms/step - loss: 0.1506 - accuracy: 0.9899 - IOU: 0.7397 - dice_coef: 0.8494 - val_loss: 0.1313 - val_accuracy: 0.9893 - val_IOU: 0.7695 - val_dice_coef: 0.8687 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 92/100
# 27/27 [==============================] - 4s 155ms/step - loss: 0.1540 - accuracy: 0.9895 - IOU: 0.7351 - dice_coef: 0.8460 - val_loss: 0.1258 - val_accuracy: 0.9902 - val_IOU: 0.7783 - val_dice_coef: 0.8742 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 93/100
# 27/27 [==============================] - 4s 149ms/step - loss: 0.1519 - accuracy: 0.9898 - IOU: 0.7379 - dice_coef: 0.8481 - val_loss: 0.1547 - val_accuracy: 0.9884 - val_IOU: 0.7327 - val_dice_coef: 0.8453 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 94/100
# 27/27 [==============================] - 4s 153ms/step - loss: 0.1461 - accuracy: 0.9903 - IOU: 0.7468 - dice_coef: 0.8539 - val_loss: 0.1237 - val_accuracy: 0.9906 - val_IOU: 0.7817 - val_dice_coef: 0.8763 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 95/100
# 27/27 [==============================] - 4s 154ms/step - loss: 0.1554 - accuracy: 0.9896 - IOU: 0.7340 - dice_coef: 0.8446 - val_loss: 0.1239 - val_accuracy: 0.9905 - val_IOU: 0.7810 - val_dice_coef: 0.8761 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 96/100
# 27/27 [==============================] - 4s 158ms/step - loss: 0.1531 - accuracy: 0.9899 - IOU: 0.7366 - dice_coef: 0.8469 - val_loss: 0.1198 - val_accuracy: 0.9906 - val_IOU: 0.7881 - val_dice_coef: 0.8802 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 97/100
# 27/27 [==============================] - 4s 154ms/step - loss: 0.1488 - accuracy: 0.9900 - IOU: 0.7424 - dice_coef: 0.8512 - val_loss: 0.1253 - val_accuracy: 0.9903 - val_IOU: 0.7789 - val_dice_coef: 0.8747 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 98/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.1468 - accuracy: 0.9901 - IOU: 0.7459 - dice_coef: 0.8532 - val_loss: 0.1207 - val_accuracy: 0.9908 - val_IOU: 0.7859 - val_dice_coef: 0.8793 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 99/100
# 27/27 [==============================] - 4s 156ms/step - loss: 0.1473 - accuracy: 0.9901 - IOU: 0.7450 - dice_coef: 0.8527 - val_loss: 0.1290 - val_accuracy: 0.9903 - val_IOU: 0.7729 - val_dice_coef: 0.8710 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 100/100
# 27/27 [==============================] - 4s 159ms/step - loss: 0.1522 - accuracy: 0.9899 - IOU: 0.7378 - dice_coef: 0.8478 - val_loss: 0.1282 - val_accuracy: 0.9899 - val_IOU: 0.7749 - val_dice_coef: 0.8718 - lr: 5.0000e-04

# %%
history = model.fit(
    tg, 
    steps_per_epoch=train_steps,
    initial_epoch =60,
    epochs=80,
    validation_data = vg,    
    validation_steps = valid_steps,callbacks=callbacks)
# Out:
# Learning rate:  0.0005
# Epoch 61/80
# 27/27 [==============================] - 7s 268ms/step - loss: 0.1615 - accuracy: 0.9892 - IOU: 0.7245 - dice_coef: 0.8385 - val_loss: 0.1477 - val_accuracy: 0.9904 - val_IOU: 0.7448 - val_dice_coef: 0.8523 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 62/80
# 27/27 [==============================] - 7s 272ms/step - loss: 0.1603 - accuracy: 0.9889 - IOU: 0.7265 - dice_coef: 0.8397 - val_loss: 0.1323 - val_accuracy: 0.9909 - val_IOU: 0.7684 - val_dice_coef: 0.8677 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 63/80
# 27/27 [==============================] - 8s 279ms/step - loss: 0.1623 - accuracy: 0.9891 - IOU: 0.7239 - dice_coef: 0.8377 - val_loss: 0.1712 - val_accuracy: 0.9892 - val_IOU: 0.7122 - val_dice_coef: 0.8288 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 64/80
# 27/27 [==============================] - 8s 282ms/step - loss: 0.1629 - accuracy: 0.9889 - IOU: 0.7223 - dice_coef: 0.8371 - val_loss: 0.1514 - val_accuracy: 0.9901 - val_IOU: 0.7398 - val_dice_coef: 0.8486 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 65/80
# 27/27 [==============================] - 8s 280ms/step - loss: 0.1574 - accuracy: 0.9894 - IOU: 0.7306 - dice_coef: 0.8426 - val_loss: 0.1607 - val_accuracy: 0.9897 - val_IOU: 0.7264 - val_dice_coef: 0.8393 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 66/80
# 27/27 [==============================] - 7s 275ms/step - loss: 0.1561 - accuracy: 0.9894 - IOU: 0.7330 - dice_coef: 0.8439 - val_loss: 0.1652 - val_accuracy: 0.9893 - val_IOU: 0.7205 - val_dice_coef: 0.8348 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 67/80
# 27/27 [==============================] - 7s 271ms/step - loss: 0.1574 - accuracy: 0.9894 - IOU: 0.7305 - dice_coef: 0.8426 - val_loss: 0.1710 - val_accuracy: 0.9888 - val_IOU: 0.7109 - val_dice_coef: 0.8290 - lr: 1.5811e-04
# Learning rate:  0.0005
# Epoch 68/80
# 27/27 [==============================] - 7s 269ms/step - loss: 0.1702 - accuracy: 0.9882 - IOU: 0.7119 - dice_coef: 0.8298 - val_loss: 0.1904 - val_accuracy: 0.9882 - val_IOU: 0.6852 - val_dice_coef: 0.8096 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 69/80
# 27/27 [==============================] - 7s 268ms/step - loss: 0.1683 - accuracy: 0.9886 - IOU: 0.7147 - dice_coef: 0.8317 - val_loss: 0.1615 - val_accuracy: 0.9897 - val_IOU: 0.7244 - val_dice_coef: 0.8385 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 70/80
# 27/27 [==============================] - 7s 269ms/step - loss: 0.1604 - accuracy: 0.9891 - IOU: 0.7261 - dice_coef: 0.8396 - val_loss: 0.1576 - val_accuracy: 0.9895 - val_IOU: 0.7291 - val_dice_coef: 0.8424 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 71/80
# 27/27 [==============================] - 7s 268ms/step - loss: 0.1623 - accuracy: 0.9889 - IOU: 0.7236 - dice_coef: 0.8377 - val_loss: 0.1380 - val_accuracy: 0.9909 - val_IOU: 0.7598 - val_dice_coef: 0.8620 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 72/80
# 27/27 [==============================] - 7s 270ms/step - loss: 0.1591 - accuracy: 0.9892 - IOU: 0.7281 - dice_coef: 0.8409 - val_loss: 0.1490 - val_accuracy: 0.9902 - val_IOU: 0.7416 - val_dice_coef: 0.8510 - lr: 1.5811e-04
# Learning rate:  0.0005
# Epoch 73/80
# 27/27 [==============================] - 7s 271ms/step - loss: 0.1599 - accuracy: 0.9891 - IOU: 0.7273 - dice_coef: 0.8401 - val_loss: 0.1454 - val_accuracy: 0.9905 - val_IOU: 0.7478 - val_dice_coef: 0.8546 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 74/80
# 27/27 [==============================] - 7s 272ms/step - loss: 0.1583 - accuracy: 0.9892 - IOU: 0.7296 - dice_coef: 0.8417 - val_loss: 0.1754 - val_accuracy: 0.9888 - val_IOU: 0.7034 - val_dice_coef: 0.8246 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 75/80
# 27/27 [==============================] - 7s 275ms/step - loss: 0.1553 - accuracy: 0.9896 - IOU: 0.7334 - dice_coef: 0.8447 - val_loss: 0.1375 - val_accuracy: 0.9907 - val_IOU: 0.7596 - val_dice_coef: 0.8625 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 76/80
# 27/27 [==============================] - 7s 274ms/step - loss: 0.1544 - accuracy: 0.9896 - IOU: 0.7354 - dice_coef: 0.8456 - val_loss: 0.1520 - val_accuracy: 0.9902 - val_IOU: 0.7376 - val_dice_coef: 0.8480 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 77/80
# 27/27 [==============================] - 7s 275ms/step - loss: 0.1533 - accuracy: 0.9897 - IOU: 0.7365 - dice_coef: 0.8467 - val_loss: 0.1945 - val_accuracy: 0.9880 - val_IOU: 0.6770 - val_dice_coef: 0.8055 - lr: 1.5811e-04
# Learning rate:  0.0005
# Epoch 78/80
# 27/27 [==============================] - 7s 273ms/step - loss: 0.1642 - accuracy: 0.9890 - IOU: 0.7212 - dice_coef: 0.8358 - val_loss: 0.1651 - val_accuracy: 0.9888 - val_IOU: 0.7199 - val_dice_coef: 0.8349 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 79/80
# 27/27 [==============================] - 7s 272ms/step - loss: 0.1620 - accuracy: 0.9888 - IOU: 0.7233 - dice_coef: 0.8380 - val_loss: 0.2375 - val_accuracy: 0.9856 - val_IOU: 0.6186 - val_dice_coef: 0.7625 - lr: 5.0000e-04
# Learning rate:  0.0005
# Epoch 80/80
# 27/27 [==============================] - 7s 271ms/step - loss: 0.1575 - accuracy: 0.9893 - IOU: 0.7302 - dice_coef: 0.8425 - val_loss: 0.1698 - val_accuracy: 0.9891 - val_IOU: 0.7137 - val_dice_coef: 0.8302 - lr: 5.0000e-04

# %%
train_loss = history.history['loss']
valid_loss = history.history['val_loss']

train_acc = history.history['accuracy']
valid_acc = history.history['val_accuracy']

# %%
fig, axes = plt.subplots(1, 2, figsize=(13,4))
axes = axes.flatten()

axes[0].plot(train_acc, label='training')
axes[0].plot(valid_acc, label='validation')
axes[0].set_title('Accuracy Curve')
axes[0].set_xlabel('epochs')
axes[0].set_ylabel('accuracy')
axes[0].legend()


axes[1].plot(train_loss, label='training')
axes[1].plot(valid_loss, label='validation')
axes[1].set_title('Loss Curve')
axes[1].set_xlabel('epochs')
axes[1].set_ylabel('loss')
axes[1].legend()

plt.show()

# %%
train_dice = history.history['dice_coef']
valid_dice = history.history['val_dice_coef']


train_IOU = history.history['IOU']
valid_IOU = history.history['val_IOU']

# %%
fig, axes = plt.subplots(1, 2, figsize=(20,7))
axes = axes.flatten()

axes[0].plot(train_IOU, label='training')
axes[0].plot(valid_IOU, label='validation')
axes[0].set_title('IOU Curve [Adam lr : 0.0001]')
axes[0].set_xlabel('epochs')
axes[0].set_ylabel('IOU')
axes[0].legend()


axes[1].plot(train_dice, label='training')
axes[1].plot(valid_dice, label='validation')
axes[1].set_title('Dice coefficient Curve [Adam lr : 0.0001]')
axes[1].set_xlabel('epochs')
axes[1].set_ylabel('dice_coef')
axes[1].legend()

plt.show()

# %% [markdown]
# ## Testing

# %%
test_generator = Generator(valid_image_files, valid_mask_files,30 , img_dim)

for x_test, y_test in test_generator:
  break

y_pred = model.predict(x_test)

yy_true = (y_test>0.5).flatten()
yy_pred = (y_pred>0.5).flatten()

# %%
report = classification_report(yy_true, yy_pred, output_dict=True)

Accuracy = accuracy_score(yy_true, yy_pred)

Precision = report['True']['precision']
Recall = report['True']['recall']
F1_score = report['True']['f1-score']

Sensitivity = Recall
Specificity = report['False']['recall']

AUC = roc_auc_score(y_test.flatten(), y_pred.flatten())

IOU = (Precision*Recall)/(Precision+Recall-Precision*Recall)

print("Accuracy: {0:.4f}\n".format(Accuracy))
print("Precision: {0:.4f}\n".format(Precision))
print("Recall: {0:.4f}\n".format(Recall))
print("F1-Score: {0:.4f}\n".format(F1_score))
print("Sensitivity: {0:.4f}\n".format(Sensitivity))
print("Specificity: {0:.4f}\n".format(Specificity))
print("AUC: {0:.4f}\n".format(AUC))
print("IOU: {0:.4f}\n".format(IOU))
print('-'*50,'\n')
print(classification_report(yy_true, yy_pred))
# Out:
# Accuracy: 0.9899
#
# Precision: 0.8536
#
# Recall: 0.9050
#
# F1-Score: 0.8786
#
# Sensitivity: 0.9050
#
# Specificity: 0.9935
#
# AUC: 0.9712
#
# IOU: 0.7834
#
# --------------------------------------------------
#
#               precision    recall  f1-score   support
#
#        False       1.00      0.99      0.99   1886856
#         True       0.85      0.91      0.88     79224
#
#     accuracy                           0.99   1966080
#    macro avg       0.92      0.95      0.94   1966080
# weighted avg       0.99      0.99      0.99   1966080

# %%
test_generator = Generator(test_image_paths, test_mask_paths,237, img_dim)

for x_test, y_test in test_generator:
  break

y_pred = model.predict(x_test)

yy_true = (y_test>0.5).flatten()
yy_pred = (y_pred>0.5).flatten()

# %%
report = classification_report(yy_true, yy_pred, output_dict=True)

Accuracy = accuracy_score(yy_true, yy_pred)

Precision = report['True']['precision']
Recall = report['True']['recall']
F1_score = report['True']['f1-score']

Sensitivity = Recall
Specificity = report['False']['recall']

AUC = roc_auc_score(y_test.flatten(), y_pred.flatten())

IOU = (Precision*Recall)/(Precision+Recall-Precision*Recall)

print("Accuracy: {0:.4f}\n".format(Accuracy))
print("Precision: {0:.4f}\n".format(Precision))
print("Recall: {0:.4f}\n".format(Recall))
print("F1-Score: {0:.4f}\n".format(F1_score))
print("Sensitivity: {0:.4f}\n".format(Sensitivity))
print("Specificity: {0:.4f}\n".format(Specificity))
print("AUC: {0:.4f}\n".format(AUC))
print("IOU: {0:.4f}\n".format(IOU))
print('-'*50,'\n')
print(classification_report(yy_true, yy_pred))
# Out:
# Accuracy: 0.9859
#
# Precision: 0.9214
#
# Recall: 0.7739
#
# F1-Score: 0.8412
#
# Sensitivity: 0.7739
#
# Specificity: 0.9966
#
# AUC: 0.9115
#
# IOU: 0.7260
#
# --------------------------------------------------
#
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      0.99  14780073
#         True       0.92      0.77      0.84    751959
#
#     accuracy                           0.99  15532032
#    macro avg       0.96      0.89      0.92  15532032
# weighted avg       0.99      0.99      0.99  15532032
